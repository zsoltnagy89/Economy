# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import yfinance as yf
import datetime

from valueinvesting import utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = True
X=10
currency_pair = 'USD=X'
numbers_in_currency = 'USD'
share_name = 'MOS'

# %% [markdown]
# # 1.1 Calculate Share numbers from total distributed dividend (CFS) and dividend amount

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../data/input/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date', 'real_date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../data/extras/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2014-06-30     2440 -1919           521         250  2367      604
# 1 2014-09-30     2251 -1836           415         207  2971      574
# 2 2014-12-31     2379 -1800           579         354  2375      754
# 3 2015-03-31     2139 -1720           419         296  2517      661
# 4 2015-06-30     2488 -1880           608         390  2210      627
#
#    inventory  curr_assets  goodwill  ...  acc_pay  short_term_debt  \
# 0       1580         5189      1793  ...      750               13
# 1       1472         5660      1741  ...      762                0
# 2       1718         5216      1807  ...      797               14
# 3       1523         5251      1687  ...      707               10
# 4       1612         5100      1710  ...      858               27
#
#    current_debt  curr_liab  long_term_debt  total_liab  \
# 0             1       1923            3013        7048
# 1            41       1549            3774        7511
# 2            41       1597            3778        7580
# 3            41       1620            3775        7440
# 4            57       1882            3762        7640
#
#    cash_from_operating_activities  capex  shares  real_date
# 0                             796   -214   375.6 2014-08-04
# 1                             357   -188   375.6 2014-11-04
# 2                             342   -252   375.6 2015-02-21
# 3                             729   -230   360.3 2015-05-05
# 4                             603   -227   360.3 2015-08-04
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 35 2023-03-31 2023-05-05   333.2     3604 -2934           670         428
# 36 2023-06-30 2023-08-04   333.2     3394 -2823           571         366
# 37 2023-09-30 2023-11-04   333.2     3548 -3139           410         -13
# 38 2023-12-31 2024-02-21   333.2     3150 -2590           560         368
# 39 2024-03-31 2024-04-29   323.5     2679 -2280           399          19
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 35   465     1426       3320  ...                  0         22858     1571
# 36   626     1222       3149  ...                  0         23140     1826
# 37   591     1399       2453  ...                  0         22654     1706
# 38   349     1269       2523  ...                  0         23033     1567
# 39   336     1212       2603  ...                  0         22873     1586
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 35              855           980       5167            2409       10964
# 36              229           970       4840            2423       10735
# 37              300           955       4696            2402       10604
# 38              400           130       3874            3232       10743
# 39              267           128       4020            3221       10710
#
#     cash_from_operating_activities  capex
# 35                             149   -322
# 36                            1073   -310
# 37                             647   -412
# 38                             538   -359
# 39                             -80   -383
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
if currency_pair != 'USD=X':
    data['usd_nat_currency'] = utils.daily_price(
        ticker=currency_pair,
        end=data['date'],
        days_earlier=90
        )
else:
    data['usd_nat_currency'] = [1 for x in range(len(data))]

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 35 2023-03-31 2023-05-05   333.2     3604 -2934           670         428
# 36 2023-06-30 2023-08-04   333.2     3394 -2823           571         366
# 37 2023-09-30 2023-11-04   333.2     3548 -3139           410         -13
# 38 2023-12-31 2024-02-21   333.2     3150 -2590           560         368
# 39 2024-03-31 2024-04-29   323.5     2679 -2280           399          19
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 35   465     1426       3320  ...         22858     1571              855
# 36   626     1222       3149  ...         23140     1826              229
# 37   591     1399       2453  ...         22654     1706              300
# 38   349     1269       2523  ...         23033     1567              400
# 39   336     1212       2603  ...         22873     1586              267
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 35           980       5167            2409       10964
# 36           970       4840            2423       10735
# 37           955       4696            2402       10604
# 38           130       3874            3232       10743
# 39           128       4020            3221       10710
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 35                             149   -322                 1
# 36                            1073   -310                 1
# 37                             647   -412                 1
# 38                             538   -359                 1
# 39                             -80   -383                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date  shares  revenue    cogs  gross_profit  net_profit  \
# 35 2023-03-31 2023-05-05   333.2   3604.0 -2934.0         670.0       428.0
# 36 2023-06-30 2023-08-04   333.2   3394.0 -2823.0         571.0       366.0
# 37 2023-09-30 2023-11-04   333.2   3548.0 -3139.0         410.0       -13.0
# 38 2023-12-31 2024-02-21   333.2   3150.0 -2590.0         560.0       368.0
# 39 2024-03-31 2024-04-29   323.5   2679.0 -2280.0         399.0        19.0
#
#      cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 35  465.0   1426.0     3320.0  ...       22858.0   1571.0            855.0
# 36  626.0   1222.0     3149.0  ...       23140.0   1826.0            229.0
# 37  591.0   1399.0     2453.0  ...       22654.0   1706.0            300.0
# 38  349.0   1269.0     2523.0  ...       23033.0   1567.0            400.0
# 39  336.0   1212.0     2603.0  ...       22873.0   1586.0            267.0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 35         980.0     5167.0          2409.0     10964.0
# 36         970.0     4840.0          2423.0     10735.0
# 37         955.0     4696.0          2402.0     10604.0
# 38         130.0     3874.0          3232.0     10743.0
# 39         128.0     4020.0          3221.0     10710.0
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 35                           149.0 -322.0                 1
# 36                          1073.0 -310.0                 1
# 37                           647.0 -412.0                 1
# 38                           538.0 -359.0                 1
# 39                           -80.0 -383.0                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr)

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %% [markdown]
# ## Calculate performance parameters (current ratio, ROA, ROE, margins, D/E)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr)

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share  shares  fcf  \
# 0 2014-08-04    38.515560 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
# 1 2014-08-11    38.657032 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
# 2 2014-08-18    39.505913 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
# 3 2014-08-25    39.747261 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
# 4 2014-09-01    39.331131 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
#
#    fcf_per_share    cash  ...  equity_ratio  debt_ratio  acc_rec_ratio  \
# 0            0.0  2367.0  ...      0.614737    0.385263            0.0
# 1            0.0  2367.0  ...      0.614737    0.385263            0.0
# 2            0.0  2367.0  ...      0.614737    0.385263            0.0
# 3            0.0  2367.0  ...      0.614737    0.385263            0.0
# 4            0.0  2367.0  ...      0.614737    0.385263            0.0
#
#    acc_pay_ratio  cash_turnover  inventory_turnover  gross_profit_margin  \
# 0            0.0            0.0                 0.0             0.213525
# 1            0.0            0.0                 0.0             0.213525
# 2            0.0            0.0                 0.0             0.213525
# 3            0.0            0.0                 0.0             0.213525
# 4            0.0            0.0                 0.0             0.213525
#
#    net_profit_margin  roa  roe
# 0           0.102459  0.0  0.0
# 1           0.102459  0.0  0.0
# 2           0.102459  0.0  0.0
# 3           0.102459  0.0  0.0
# 4           0.102459  0.0  0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share  shares  fcf  \
# 0 2014-08-04    38.515560 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
# 1 2014-08-11    38.657032 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
# 2 2014-08-18    39.505913 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
# 3 2014-08-25    39.747261 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
# 4 2014-09-01    39.331131 2014-06-30   2440.0  0.0     29.941427   375.6  0.0
#
#    fcf_per_share    cash  ...  inventory_turnover  gross_profit_margin  \
# 0            0.0  2367.0  ...                 0.0             0.213525
# 1            0.0  2367.0  ...                 0.0             0.213525
# 2            0.0  2367.0  ...                 0.0             0.213525
# 3            0.0  2367.0  ...                 0.0             0.213525
# 4            0.0  2367.0  ...                 0.0             0.213525
#
#    net_profit_margin  roa  roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# 0           0.102459  0.0  0.0       inf  1.286364       inf         inf
# 1           0.102459  0.0  0.0       inf  1.291088       inf         inf
# 2           0.102459  0.0  0.0       inf  1.319440       inf         inf
# 3           0.102459  0.0  0.0       inf  1.327501       inf         inf
# 4           0.102459  0.0  0.0       inf  1.313602       inf         inf
#
#    pfcf_ratio
# 0         inf
# 1         inf
# 2         inf
# 3         inf
# 4         inf
#
# [5 rows x 32 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate   NaN
# share_price     NaN
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.998099 -0.158632  0.527240  0.191262   -0.233117
# roe             0.998099  1.000000 -0.145634  0.546190  0.210021   -0.201084
# pe_ratio       -0.158632 -0.145634  1.000000 -0.188263 -0.144459   -0.025792
# pb_ratio        0.527240  0.546190 -0.188263  1.000000  0.728411    0.433491
# ps_ratio        0.191262  0.210021 -0.144459  0.728411  1.000000    0.864557
# ev_revenue     -0.233117 -0.201084 -0.025792  0.433491  0.864557    1.000000
# debt_to_equity -0.141859 -0.132321  0.062126  0.021586 -0.116485    0.141217
# current_ratio  -0.197412 -0.206494 -0.007970  0.066749  0.243613    0.095198
#
#                 debt_to_equity  current_ratio
# roa                  -0.141859      -0.197412
# roe                  -0.132321      -0.206494
# pe_ratio              0.062126      -0.007970
# pb_ratio              0.021586       0.066749
# ps_ratio             -0.116485       0.243613
# ev_revenue            0.141217       0.095198
# debt_to_equity        1.000000      -0.707563
# current_ratio        -0.707563       1.000000

# %%
final_df = utils.get_value_stock_target_prices(
    input_df=merged_nat_curr,
    min_pct=0.2,
    max_pct=0.5,
    owned_shares=owned_shares
)
