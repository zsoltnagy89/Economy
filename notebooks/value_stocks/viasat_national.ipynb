# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import yfinance as yf
import datetime

from valueinvesting import utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = True
X=10
currency_pair = 'USD=X'
numbers_in_currency = 'USD'
share_name = 'VSAT'

# %% [markdown]
# # 1.1 Calculate Share numbers from total distributed dividend (CFS) and dividend amount

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../data/input/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date', 'real_date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../data/extras/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2014-07-01      320  -238            82          -6    58      279
# 1 2014-10-01      359  -242           117          24    42      280
# 2 2015-01-01      340  -234           106          15    98      268
# 3 2015-04-01      365  -251           114           7    52      266
# 4 2015-06-30      344  -243           101           2    42      295
#
#    inventory  curr_assets  goodwill  ...  acc_pay  short_term_debt  \
# 0        129          541       118  ...       86                0
# 1        127          526       118  ...       74                0
# 2        129          577       117  ...       82                0
# 3        128          491       117  ...       77                0
# 4        127          570       118  ...       73                0
#
#    current_debt  curr_liab  long_term_debt  total_liab  \
# 0             2        252             789        1094
# 1             1        245             724        1018
# 2             1        269             819        1134
# 3             0        268             806        1120
# 4             0        227             861        1133
#
#    cash_from_operating_activities  capex  shares  real_date
# 0                              47    -98   48.28 2014-08-10
# 1                             112    -64   48.28 2014-11-10
# 2                             113   -149   48.28 2015-02-10
# 3                              78   -109   48.28 2015-05-31
# 4                              18    -83   49.44 2015-08-09
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 35 2023-03-31 2023-05-30   76.91      666  -492           174         -59
# 36 2023-06-30 2023-08-09  124.05      780  -545           235         -78
# 37 2023-09-30 2023-11-09  124.53     1225  -766           459        -765
# 38 2023-12-31 2024-02-09  125.32     1129  -767           361        -122
# 39 2024-03-31 2024-05-20  125.90     1150  -823           322         -85
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 35  1349      420        269  ...                497          7730      272
# 36  1959      631        336  ...               2847         17898      378
# 37  1962      664        346  ...               3074         17072      389
# 38  1571      676        354  ...               3112         16651      315
# 39  1901      678        318  ...               2937         16329      287
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 35                0            38        957            2422        3906
# 36                0            60       1472            7218       11958
# 37                0            63       1550            7228       11882
# 38                0            63       1377            7223       11548
# 39                0            58       1295            7129       11256
#
#     cash_from_operating_activities  capex
# 35                              50   -314
# 36                             104   -375
# 37                             219   -366
# 38                             134   -421
# 39                             232   -378
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
if currency_pair != 'USD=X':
    data['usd_nat_currency'] = utils.daily_price(
        ticker=currency_pair,
        end=data['date'],
        days_earlier=90
        )
else:
    data['usd_nat_currency'] = [1 for x in range(len(data))]

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 35 2023-03-31 2023-05-30   76.91      666  -492           174         -59
# 36 2023-06-30 2023-08-09  124.05      780  -545           235         -78
# 37 2023-09-30 2023-11-09  124.53     1225  -766           459        -765
# 38 2023-12-31 2024-02-09  125.32     1129  -767           361        -122
# 39 2024-03-31 2024-05-20  125.90     1150  -823           322         -85
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 35  1349      420        269  ...          7730      272                0
# 36  1959      631        336  ...         17898      378                0
# 37  1962      664        346  ...         17072      389                0
# 38  1571      676        354  ...         16651      315                0
# 39  1901      678        318  ...         16329      287                0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 35            38        957            2422        3906
# 36            60       1472            7218       11958
# 37            63       1550            7228       11882
# 38            63       1377            7223       11548
# 39            58       1295            7129       11256
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 35                              50   -314                 1
# 36                             104   -375                 1
# 37                             219   -366                 1
# 38                             134   -421                 1
# 39                             232   -378                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date  shares  revenue   cogs  gross_profit  net_profit  \
# 35 2023-03-31 2023-05-30   76.91    666.0 -492.0         174.0       -59.0
# 36 2023-06-30 2023-08-09  124.05    780.0 -545.0         235.0       -78.0
# 37 2023-09-30 2023-11-09  124.53   1225.0 -766.0         459.0      -765.0
# 38 2023-12-31 2024-02-09  125.32   1129.0 -767.0         361.0      -122.0
# 39 2024-03-31 2024-05-20  125.90   1150.0 -823.0         322.0       -85.0
#
#       cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 35  1349.0    420.0      269.0  ...        7730.0    272.0              0.0
# 36  1959.0    631.0      336.0  ...       17898.0    378.0              0.0
# 37  1962.0    664.0      346.0  ...       17072.0    389.0              0.0
# 38  1571.0    676.0      354.0  ...       16651.0    315.0              0.0
# 39  1901.0    678.0      318.0  ...       16329.0    287.0              0.0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 35          38.0      957.0          2422.0      3906.0
# 36          60.0     1472.0          7218.0     11958.0
# 37          63.0     1550.0          7228.0     11882.0
# 38          63.0     1377.0          7223.0     11548.0
# 39          58.0     1295.0          7129.0     11256.0
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 35                            50.0 -314.0                 1
# 36                           104.0 -375.0                 1
# 37                           219.0 -366.0                 1
# 38                           134.0 -421.0                 1
# 39                           232.0 -378.0                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr)

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %% [markdown]
# ## Calculate performance parameters (current ratio, ROA, ROE, margins, D/E)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr)

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share  shares  fcf  \
# 0 2014-08-11    54.470001 2014-07-01    320.0  0.0     19.925435   48.28  0.0
# 1 2014-08-18    56.930000 2014-07-01    320.0  0.0     19.925435   48.28  0.0
# 2 2014-08-25    56.939999 2014-07-01    320.0  0.0     19.925435   48.28  0.0
# 3 2014-09-01    57.590000 2014-07-01    320.0  0.0     19.925435   48.28  0.0
# 4 2014-09-08    57.840000 2014-07-01    320.0  0.0     19.925435   48.28  0.0
#
#    fcf_per_share  cash  ...  equity_ratio  debt_ratio  acc_rec_ratio  \
# 0            0.0  58.0  ...      0.467899    0.532101            0.0
# 1            0.0  58.0  ...      0.467899    0.532101            0.0
# 2            0.0  58.0  ...      0.467899    0.532101            0.0
# 3            0.0  58.0  ...      0.467899    0.532101            0.0
# 4            0.0  58.0  ...      0.467899    0.532101            0.0
#
#    acc_pay_ratio  cash_turnover  inventory_turnover  gross_profit_margin  \
# 0            0.0            0.0                 0.0              0.25625
# 1            0.0            0.0                 0.0              0.25625
# 2            0.0            0.0                 0.0              0.25625
# 3            0.0            0.0                 0.0              0.25625
# 4            0.0            0.0                 0.0              0.25625
#
#    net_profit_margin  roa  roe
# 0           -0.01875  0.0  0.0
# 1           -0.01875  0.0  0.0
# 2           -0.01875  0.0  0.0
# 3           -0.01875  0.0  0.0
# 4           -0.01875  0.0  0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share  shares  fcf  \
# 0 2014-08-11    54.470001 2014-07-01    320.0  0.0     19.925435   48.28  0.0
# 1 2014-08-18    56.930000 2014-07-01    320.0  0.0     19.925435   48.28  0.0
# 2 2014-08-25    56.939999 2014-07-01    320.0  0.0     19.925435   48.28  0.0
# 3 2014-09-01    57.590000 2014-07-01    320.0  0.0     19.925435   48.28  0.0
# 4 2014-09-08    57.840000 2014-07-01    320.0  0.0     19.925435   48.28  0.0
#
#    fcf_per_share  cash  ...  inventory_turnover  gross_profit_margin  \
# 0            0.0  58.0  ...                 0.0              0.25625
# 1            0.0  58.0  ...                 0.0              0.25625
# 2            0.0  58.0  ...                 0.0              0.25625
# 3            0.0  58.0  ...                 0.0              0.25625
# 4            0.0  58.0  ...                 0.0              0.25625
#
#    net_profit_margin  roa  roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# 0           -0.01875  0.0  0.0       inf  2.733692       inf         inf
# 1           -0.01875  0.0  0.0       inf  2.857152       inf         inf
# 2           -0.01875  0.0  0.0       inf  2.857654       inf         inf
# 3           -0.01875  0.0  0.0       inf  2.890276       inf         inf
# 4           -0.01875  0.0  0.0       inf  2.902822       inf         inf
#
#    pfcf_ratio
# 0         inf
# 1         inf
# 2         inf
# 3         inf
# 4         inf
#
# [5 rows x 32 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate   NaN
# share_price     NaN
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.976387  0.444811  0.663192  0.562751   -0.089765
# roe             0.976387  1.000000  0.361139  0.664353  0.609702   -0.101506
# pe_ratio        0.444811  0.361139  1.000000  0.056477 -0.098183   -0.351929
# pb_ratio        0.663192  0.664353  0.056477  1.000000  0.910846    0.280203
# ps_ratio        0.562751  0.609702 -0.098183  0.910846  1.000000    0.429162
# ev_revenue     -0.089765 -0.101506 -0.351929  0.280203  0.429162    1.000000
# debt_to_equity -0.666860 -0.759105 -0.055781 -0.668270 -0.799072    0.082705
# current_ratio  -0.047452 -0.198834  0.047185  0.083413 -0.051337    0.221232
#
#                 debt_to_equity  current_ratio
# roa                  -0.666860      -0.047452
# roe                  -0.759105      -0.198834
# pe_ratio             -0.055781       0.047185
# pb_ratio             -0.668270       0.083413
# ps_ratio             -0.799072      -0.051337
# ev_revenue            0.082705       0.221232
# debt_to_equity        1.000000       0.225583
# current_ratio         0.225583       1.000000

# %%
final_df = utils.get_value_stock_target_prices(
    input_df=merged_nat_curr,
    min_pct=0.2,
    max_pct=0.5,
    owned_shares=owned_shares
)
