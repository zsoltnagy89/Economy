# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import yfinance as yf
import datetime

from valueinvesting import utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = True
X=10
currency_pair = 'CAD=X'
numbers_in_currency = 'CAD'
share_name = 'CTC-A.TO'

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../data/input/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date', 'real_date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../data/extras/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2014-06-30     3166 -2153          1013         179   308      534
# 1 2014-09-30     3070 -2085           985         178   410      845
# 2 2014-12-31     3654 -2440          1214         207   662      880
# 3 2015-03-31     2515 -1633           882          88   291     1105
# 4 2015-06-30     3258 -2206          1052         186  1076      664
#
#    inventory  curr_assets  goodwill  ...  acc_pay  short_term_debt  \
# 0       1555         7385         0  ...     1706                0
# 1       1973         8251         0  ...     2040                0
# 2       1624         8510         0  ...     1961                0
# 3       1891         8452         0  ...     1897                0
# 4       1769         8732         0  ...     1795                0
#
#    current_debt  curr_liab  long_term_debt  total_liab  \
# 0           319       4092            1841        7577
# 1           321       4542            2394        8591
# 2           588       4579            2132        8922
# 3           587       4434            2130        8869
# 4           288       3925            2974        9232
#
#    cash_from_operating_activities  capex  shares  real_date
# 0                             306     21   80.09 2014-08-09
# 1                            -173   -261   79.21 2014-11-09
# 2                            -484   -388   78.46 2015-02-14
# 3                            -185    -75   77.90 2015-05-10
# 4                             550    -75   77.28 2015-08-09
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 35 2023-03-31 2023-05-10   57.43     3707 -2425          1282          43
# 36 2023-06-30 2023-08-09   56.55     4256 -2807          1449         127
# 37 2023-09-30 2023-11-09   55.76     4250 -2814          1436         -28
# 38 2023-12-31 2024-02-14   55.76     4443 -2906          1537         197
# 39 2024-03-31 2024-05-06   55.76     3524 -2274          1250          96
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 35   312     1508       3280  ...               2288         22163     2849
# 36   433      863       3214  ...               2248         21840     2926
# 37   459     1524       3360  ...               2256         22713     2990
# 38   311     1151       2693  ...               2255         21978     2689
# 39   592     1468       2782  ...               2201         22426     2782
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 35                0           985       7498            3218       15460
# 36                0          1545       7704            2659       15283
# 37                0           561       6999            3754       16212
# 38                0           561       6389            4404       15533
# 39                0           561       6746            4405       15975
#
#     cash_from_operating_activities  capex
# 35                            -311   -159
# 36                             823    -74
# 37                             -29   -162
# 38                             870   -353
# 39                             122   -114
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
data['usd_nat_currency'] = utils.daily_price(
    ticker=currency_pair,
    end=data['date'],
    days_earlier=90
    )

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 35 2023-03-31 2023-05-10   57.43     3707 -2425          1282          43
# 36 2023-06-30 2023-08-09   56.55     4256 -2807          1449         127
# 37 2023-09-30 2023-11-09   55.76     4250 -2814          1436         -28
# 38 2023-12-31 2024-02-14   55.76     4443 -2906          1537         197
# 39 2024-03-31 2024-05-06   55.76     3524 -2274          1250          96
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 35   312     1508       3280  ...         22163     2849                0
# 36   433      863       3214  ...         21840     2926                0
# 37   459     1524       3360  ...         22713     2990                0
# 38   311     1151       2693  ...         21978     2689                0
# 39   592     1468       2782  ...         22426     2782                0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 35           985       7498            3218       15460
# 36          1545       7704            2659       15283
# 37           561       6999            3754       16212
# 38           561       6389            4404       15533
# 39           561       6746            4405       15975
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 35                            -311   -159          1.352063
# 36                             823    -74          1.343352
# 37                             -29   -162          1.341033
# 38                             870   -353          1.361617
# 39                             122   -114          1.347550
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 35 2023-03-31 2023-05-10   57.43     3707 -2425          1282          43
# 36 2023-06-30 2023-08-09   56.55     4256 -2807          1449         127
# 37 2023-09-30 2023-11-09   55.76     4250 -2814          1436         -28
# 38 2023-12-31 2024-02-14   55.76     4443 -2906          1537         197
# 39 2024-03-31 2024-05-06   55.76     3524 -2274          1250          96
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 35   312     1508       3280  ...         22163     2849                0
# 36   433      863       3214  ...         21840     2926                0
# 37   459     1524       3360  ...         22713     2990                0
# 38   311     1151       2693  ...         21978     2689                0
# 39   592     1468       2782  ...         22426     2782                0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 35           985       7498            3218       15460
# 36          1545       7704            2659       15283
# 37           561       6999            3754       16212
# 38           561       6389            4404       15533
# 39           561       6746            4405       15975
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 35                            -311   -159          1.352063
# 36                             823    -74          1.343352
# 37                             -29   -162          1.341033
# 38                             870   -353          1.361617
# 39                             122   -114          1.347550
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr)

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr)

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data
# ## Pull historical share prices

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share  shares  fcf  \
# 0 2014-08-11    83.073380 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
# 1 2014-08-18    85.062431 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
# 2 2014-08-25    84.625443 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
# 3 2014-09-01    85.853531 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
# 4 2014-09-08    87.028915 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
#
#    fcf_per_share   cash  ...  equity_ratio  debt_ratio  acc_rec_ratio  \
# 0            0.0  308.0  ...       0.41863     0.58137            0.0
# 1            0.0  308.0  ...       0.41863     0.58137            0.0
# 2            0.0  308.0  ...       0.41863     0.58137            0.0
# 3            0.0  308.0  ...       0.41863     0.58137            0.0
# 4            0.0  308.0  ...       0.41863     0.58137            0.0
#
#    acc_pay_ratio  cash_turnover  inventory_turnover  gross_profit_margin  \
# 0            0.0            0.0                 0.0             0.319962
# 1            0.0            0.0                 0.0             0.319962
# 2            0.0            0.0                 0.0             0.319962
# 3            0.0            0.0                 0.0             0.319962
# 4            0.0            0.0                 0.0             0.319962
#
#    net_profit_margin  roa  roe
# 0           0.056538  0.0  0.0
# 1           0.056538  0.0  0.0
# 2           0.056538  0.0  0.0
# 3           0.056538  0.0  0.0
# 4           0.056538  0.0  0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share  shares  fcf  \
# 0 2014-08-11    83.073380 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
# 1 2014-08-18    85.062431 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
# 2 2014-08-25    84.625443 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
# 3 2014-09-01    85.853531 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
# 4 2014-09-08    87.028915 2014-06-30   3166.0  0.0     68.123361   80.09  0.0
#
#    fcf_per_share   cash  ...  inventory_turnover  gross_profit_margin  \
# 0            0.0  308.0  ...                 0.0             0.319962
# 1            0.0  308.0  ...                 0.0             0.319962
# 2            0.0  308.0  ...                 0.0             0.319962
# 3            0.0  308.0  ...                 0.0             0.319962
# 4            0.0  308.0  ...                 0.0             0.319962
#
#    net_profit_margin  roa  roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# 0           0.056538  0.0  0.0       inf  1.219455       inf         inf
# 1           0.056538  0.0  0.0       inf  1.248653       inf         inf
# 2           0.056538  0.0  0.0       inf  1.242238       inf         inf
# 3           0.056538  0.0  0.0       inf  1.260266       inf         inf
# 4           0.056538  0.0  0.0       inf  1.277519       inf         inf
#
#    pfcf_ratio
# 0         inf
# 1         inf
# 2         inf
# 3         inf
# 4         inf
#
# [5 rows x 32 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate   -0.010968
# share_price      1.000000
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.939876 -0.751527  0.332924  0.432138   -0.051272
# roe             0.939876  1.000000 -0.833482  0.333121  0.159591    0.255714
# pe_ratio       -0.751527 -0.833482  1.000000  0.040246  0.122419    0.117036
# pb_ratio        0.332924  0.333121  0.040246  1.000000  0.850357    0.705290
# ps_ratio        0.432138  0.159591  0.122419  0.850357  1.000000    0.403936
# ev_revenue     -0.051272  0.255714  0.117036  0.705290  0.403936    1.000000
# debt_to_equity  0.150781  0.455170 -0.084045  0.039464 -0.494366    0.552597
# current_ratio   0.085921 -0.129235  0.217236  0.214873  0.559865   -0.125264
#
#                 debt_to_equity  current_ratio
# roa                   0.150781       0.085921
# roe                   0.455170      -0.129235
# pe_ratio             -0.084045       0.217236
# pb_ratio              0.039464       0.214873
# ps_ratio             -0.494366       0.559865
# ev_revenue            0.552597      -0.125264
# debt_to_equity        1.000000      -0.532269
# current_ratio        -0.532269       1.000000

# %%
final_df = utils.get_value_stock_target_prices(
    input_df=merged_nat_curr,
    min_pct=0.2,
    max_pct=0.5,
    owned_shares=owned_shares
)
