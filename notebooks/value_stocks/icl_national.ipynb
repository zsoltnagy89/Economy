# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import yfinance as yf
import datetime

from valueinvesting import utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = True
X=10
currency_pair = 'USD=X'
numbers_in_currency = 'USD'
share_name = 'ICL'

# %% [markdown]
# # 1.1 Calculate Share numbers from total distributed dividend (CFS) and dividend amount

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../data/input/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date', 'real_date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../data/extras/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2014-06-30     1536  -993           542          68   178     1274
# 1 2014-09-30     1560  -982           578         181   177     1168
# 2 2014-12-31     1403  -890           513          85   131     1039
# 3 2015-03-31     1403  -957           446         217   165     1110
# 4 2015-06-30     1196  -860           336          75   231      882
#
#    inventory  curr_assets  goodwill  ...  acc_pay  short_term_debt  \
# 0       1351         3187         0  ...      639                0
# 1       1277         3327         0  ...      563                0
# 2       1335         3140         0  ...      585                0
# 3       1236         2960         0  ...      560                0
# 4       1201         2701         0  ...      572                0
#
#    current_debt  curr_liab  long_term_debt  total_liab  \
# 0           859       2200            2057        5307
# 1           815       2161            2088        5331
# 2           603       2003            2304        5374
# 3           798       2196            1955        5253
# 4           559       1811            2339        5215
#
#    cash_from_operating_activities  capex   shares  real_date
# 0                             120   -208  1270.46 2014-08-09
# 1                             283   -207  1270.46 2014-11-09
# 2                             318   -181  1270.46 2015-03-01
# 3                              65   -150  1272.26 2015-05-10
# 4                             326   -155  1272.26 2015-08-09
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date   shares  revenue  cogs  gross_profit  net_profit  \
# 34 2022-12-31 2023-03-01  1289.95     2091 -1158           933         342
# 35 2023-03-31 2023-05-10  1290.67     2098 -1270           828         294
# 36 2023-06-30 2023-08-09  1290.67     1834 -1189           645         167
# 37 2023-09-30 2023-11-09  1290.67     1862 -1276           586         142
# 38 2023-12-31 2024-02-29  1290.67     1690 -1130           560          84
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 34   417     1583       2134  ...                852         11750     1006
# 35   552     1631       2116  ...                867         12045      967
# 36   372     1380       2006  ...                872         11584      893
# 37   307     1387       1722  ...                851         11274      814
# 38   420     1376       1703  ...                873         11627      912
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 34                0           512       2606            2312        6286
# 35                0           704       2735            2278        6414
# 36                0           674       2431            2117        5914
# 37                0           592       2286            1984        5610
# 38                0           858       2638            1829        5590
#
#     cash_from_operating_activities  capex
# 34                             467   -212
# 35                             382   -164
# 36                             391   -170
# 37                             407   -191
# 38                             415   -255
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
if currency_pair != 'USD=X':
    data['usd_nat_currency'] = utils.daily_price(
        ticker=currency_pair,
        end=data['date'],
        days_earlier=90
        )
else:
    data['usd_nat_currency'] = [1 for x in range(len(data))]

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
#          date  real_date   shares  revenue  cogs  gross_profit  net_profit  \
# 34 2022-12-31 2023-03-01  1289.95     2091 -1158           933         342
# 35 2023-03-31 2023-05-10  1290.67     2098 -1270           828         294
# 36 2023-06-30 2023-08-09  1290.67     1834 -1189           645         167
# 37 2023-09-30 2023-11-09  1290.67     1862 -1276           586         142
# 38 2023-12-31 2024-02-29  1290.67     1690 -1130           560          84
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 34   417     1583       2134  ...         11750     1006                0
# 35   552     1631       2116  ...         12045      967                0
# 36   372     1380       2006  ...         11584      893                0
# 37   307     1387       1722  ...         11274      814                0
# 38   420     1376       1703  ...         11627      912                0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 34           512       2606            2312        6286
# 35           704       2735            2278        6414
# 36           674       2431            2117        5914
# 37           592       2286            1984        5610
# 38           858       2638            1829        5590
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 34                             467   -212                 1
# 35                             382   -164                 1
# 36                             391   -170                 1
# 37                             407   -191                 1
# 38                             415   -255                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date   shares  revenue    cogs  gross_profit  net_profit  \
# 34 2022-12-31 2023-03-01  1289.95   2091.0 -1158.0         933.0       342.0
# 35 2023-03-31 2023-05-10  1290.67   2098.0 -1270.0         828.0       294.0
# 36 2023-06-30 2023-08-09  1290.67   1834.0 -1189.0         645.0       167.0
# 37 2023-09-30 2023-11-09  1290.67   1862.0 -1276.0         586.0       142.0
# 38 2023-12-31 2024-02-29  1290.67   1690.0 -1130.0         560.0        84.0
#
#      cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 34  417.0   1583.0     2134.0  ...       11750.0   1006.0              0.0
# 35  552.0   1631.0     2116.0  ...       12045.0    967.0              0.0
# 36  372.0   1380.0     2006.0  ...       11584.0    893.0              0.0
# 37  307.0   1387.0     1722.0  ...       11274.0    814.0              0.0
# 38  420.0   1376.0     1703.0  ...       11627.0    912.0              0.0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 34         512.0     2606.0          2312.0      6286.0
# 35         704.0     2735.0          2278.0      6414.0
# 36         674.0     2431.0          2117.0      5914.0
# 37         592.0     2286.0          1984.0      5610.0
# 38         858.0     2638.0          1829.0      5590.0
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 34                           467.0 -212.0                 1
# 35                           382.0 -164.0                 1
# 36                           391.0 -170.0                 1
# 37                           407.0 -191.0                 1
# 38                           415.0 -255.0                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr)

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %% [markdown]
# ## Calculate performance parameters (current ratio, ROA, ROE, margins, D/E)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr)

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share   shares  \
# 0 2014-08-11     5.440686 2014-06-30   1536.0  0.0      2.462887  1270.46
# 1 2014-08-18     5.167981 2014-06-30   1536.0  0.0      2.462887  1270.46
# 2 2014-08-25     5.167981 2014-06-30   1536.0  0.0      2.462887  1270.46
# 3 2014-09-01     5.052066 2014-06-30   1536.0  0.0      2.462887  1270.46
# 4 2014-09-08     4.998464 2014-06-30   1536.0  0.0      2.462887  1270.46
#
#    fcf  fcf_per_share   cash  ...  equity_ratio  debt_ratio  acc_rec_ratio  \
# 0  0.0            0.0  178.0  ...       0.37091     0.62909            0.0
# 1  0.0            0.0  178.0  ...       0.37091     0.62909            0.0
# 2  0.0            0.0  178.0  ...       0.37091     0.62909            0.0
# 3  0.0            0.0  178.0  ...       0.37091     0.62909            0.0
# 4  0.0            0.0  178.0  ...       0.37091     0.62909            0.0
#
#    acc_pay_ratio  cash_turnover  inventory_turnover  gross_profit_margin  \
# 0            0.0            0.0                 0.0             0.352865
# 1            0.0            0.0                 0.0             0.352865
# 2            0.0            0.0                 0.0             0.352865
# 3            0.0            0.0                 0.0             0.352865
# 4            0.0            0.0                 0.0             0.352865
#
#    net_profit_margin  roa  roe
# 0           0.044271  0.0  0.0
# 1           0.044271  0.0  0.0
# 2           0.044271  0.0  0.0
# 3           0.044271  0.0  0.0
# 4           0.044271  0.0  0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share   shares  \
# 0 2014-08-11     5.440686 2014-06-30   1536.0  0.0      2.462887  1270.46
# 1 2014-08-18     5.167981 2014-06-30   1536.0  0.0      2.462887  1270.46
# 2 2014-08-25     5.167981 2014-06-30   1536.0  0.0      2.462887  1270.46
# 3 2014-09-01     5.052066 2014-06-30   1536.0  0.0      2.462887  1270.46
# 4 2014-09-08     4.998464 2014-06-30   1536.0  0.0      2.462887  1270.46
#
#    fcf  fcf_per_share   cash  ...  inventory_turnover  gross_profit_margin  \
# 0  0.0            0.0  178.0  ...                 0.0             0.352865
# 1  0.0            0.0  178.0  ...                 0.0             0.352865
# 2  0.0            0.0  178.0  ...                 0.0             0.352865
# 3  0.0            0.0  178.0  ...                 0.0             0.352865
# 4  0.0            0.0  178.0  ...                 0.0             0.352865
#
#    net_profit_margin  roa  roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# 0           0.044271  0.0  0.0       inf  2.209068       inf         inf
# 1           0.044271  0.0  0.0       inf  2.098342       inf         inf
# 2           0.044271  0.0  0.0       inf  2.098342       inf         inf
# 3           0.044271  0.0  0.0       inf  2.051278       inf         inf
# 4           0.044271  0.0  0.0       inf  2.029514       inf         inf
#
#    pfcf_ratio
# 0         inf
# 1         inf
# 2         inf
# 3         inf
# 4         inf
#
# [5 rows x 32 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate   NaN
# share_price     NaN
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.990097 -0.221092 -0.011251  0.077733   -0.359501
# roe             0.990097  1.000000 -0.224001  0.006215  0.085671   -0.320139
# pe_ratio       -0.221092 -0.224001  1.000000 -0.025167  0.136176    0.220577
# pb_ratio       -0.011251  0.006215 -0.025167  1.000000  0.869956    0.756736
# ps_ratio        0.077733  0.085671  0.136176  0.869956  1.000000    0.854600
# ev_revenue     -0.359501 -0.320139  0.220577  0.756736  0.854600    1.000000
# debt_to_equity -0.627837 -0.580441 -0.064155  0.121106 -0.265994    0.175595
# current_ratio   0.575844  0.535369 -0.118133 -0.059173  0.013088   -0.395124
#
#                 debt_to_equity  current_ratio
# roa                  -0.627837       0.575844
# roe                  -0.580441       0.535369
# pe_ratio             -0.064155      -0.118133
# pb_ratio              0.121106      -0.059173
# ps_ratio             -0.265994       0.013088
# ev_revenue            0.175595      -0.395124
# debt_to_equity        1.000000      -0.634907
# current_ratio        -0.634907       1.000000

# %%
final_df = utils.get_value_stock_target_prices(
    input_df=merged_nat_curr,
    min_pct=0.2,
    max_pct=0.5,
    owned_shares=owned_shares
)
