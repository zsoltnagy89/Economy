# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import yfinance as yf
import datetime

from valueinvesting import utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = True
X=10
currency_pair = 'USD=X'
numbers_in_currency = 'USD'
share_name = 'SBSW'

# %% [markdown]
# # 1.1 Calculate Share numbers from total distributed dividend (CFS) and dividend amount

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../data/input/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date', 'real_date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../data/extras/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2014-06-30      920  -594           327          50   114       75
# 1 2014-12-31     1093  -729           364          89    49       86
# 2 2015-06-30      861  -663           199           7    70       86
# 3 2015-12-31      920  -622           298          35    46      105
# 4 2016-06-30      956  -605           359           6    59      145
#
#    inventory  curr_assets  goodwill  ...  acc_pay  short_term_debt  \
# 0         27          223        69  ...      280               52
# 1         28          168        64  ...      235               48
# 2         32          189        61  ...      235               45
# 3         26          177        47  ...      178              128
# 4         38          242        66  ...      264              257
#
#    current_debt  curr_liab  long_term_debt  total_liab  \
# 0             0        415             120        1174
# 1             0        309             226        1119
# 2             0        325             261        1111
# 3             0        344             116         854
# 4             0        556             221        1257
#
#    cash_from_operating_activities  capex  shares  real_date
# 0                             234   -126     792 2014-08-29
# 1                             140   -174     915 2015-03-01
# 2                             116   -131     914 2015-08-29
# 3                             157   -131     920 2016-02-29
# 4                             161   -115     925 2016-08-29
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 15 2021-12-31 2022-03-01    2877     5461 -3821          1640         544
# 16 2022-06-30 2022-08-29    2831     4570 -3263          1307         803
# 17 2022-12-31 2023-03-01    2831     3878 -2945           933         359
# 18 2023-06-30 2023-08-29    2831     3326 -2728           598         427
# 19 2023-12-31 2024-02-29    2831     2846 -2689           157       -2459
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 15  1900      465       1573  ...                  0          9598      951
# 16  1673      437       1658  ...                  0          9736      883
# 17  1531      440       1549  ...                  0          9783      919
# 18  1176      425       1364  ...                  0          9569      816
# 19  1376      479       1420  ...                  0          7696      887
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 15                7             0       1290            1267        4496
# 16                7             0       1152            1275        4249
# 17                7             0       1187            1327        4441
# 18                7             0        957            1336        4260
# 19              834             0       1962            1343        4919
#
#     cash_from_operating_activities  capex
# 15                            1267   -477
# 16                             285   -399
# 17                             664   -572
# 18                             272   -596
# 19                             113   -621
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
if currency_pair != 'USD=X':
    data['usd_nat_currency'] = utils.daily_price(
        ticker=currency_pair,
        end=data['date'],
        days_earlier=90
        )
else:
    data['usd_nat_currency'] = [1 for x in range(len(data))]

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 15 2021-12-31 2022-03-01    2877     5461 -3821          1640         544
# 16 2022-06-30 2022-08-29    2831     4570 -3263          1307         803
# 17 2022-12-31 2023-03-01    2831     3878 -2945           933         359
# 18 2023-06-30 2023-08-29    2831     3326 -2728           598         427
# 19 2023-12-31 2024-02-29    2831     2846 -2689           157       -2459
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 15  1900      465       1573  ...          9598      951                7
# 16  1673      437       1658  ...          9736      883                7
# 17  1531      440       1549  ...          9783      919                7
# 18  1176      425       1364  ...          9569      816                7
# 19  1376      479       1420  ...          7696      887              834
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 15             0       1290            1267        4496
# 16             0       1152            1275        4249
# 17             0       1187            1327        4441
# 18             0        957            1336        4260
# 19             0       1962            1343        4919
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 15                            1267   -477                 1
# 16                             285   -399                 1
# 17                             664   -572                 1
# 18                             272   -596                 1
# 19                             113   -621                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date  shares  revenue    cogs  gross_profit  net_profit  \
# 15 2021-12-31 2022-03-01    2877   5461.0 -3821.0        1640.0       544.0
# 16 2022-06-30 2022-08-29    2831   4570.0 -3263.0        1307.0       803.0
# 17 2022-12-31 2023-03-01    2831   3878.0 -2945.0         933.0       359.0
# 18 2023-06-30 2023-08-29    2831   3326.0 -2728.0         598.0       427.0
# 19 2023-12-31 2024-02-29    2831   2846.0 -2689.0         157.0     -2459.0
#
#       cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 15  1900.0    465.0     1573.0  ...        9598.0    951.0              7.0
# 16  1673.0    437.0     1658.0  ...        9736.0    883.0              7.0
# 17  1531.0    440.0     1549.0  ...        9783.0    919.0              7.0
# 18  1176.0    425.0     1364.0  ...        9569.0    816.0              7.0
# 19  1376.0    479.0     1420.0  ...        7696.0    887.0            834.0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 15           0.0     1290.0          1267.0      4496.0
# 16           0.0     1152.0          1275.0      4249.0
# 17           0.0     1187.0          1327.0      4441.0
# 18           0.0      957.0          1336.0      4260.0
# 19           0.0     1962.0          1343.0      4919.0
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 15                          1267.0 -477.0                 1
# 16                           285.0 -399.0                 1
# 17                           664.0 -572.0                 1
# 18                           272.0 -596.0                 1
# 19                           113.0 -621.0                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr, report='half-year')

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %% [markdown]
# ## Calculate performance parameters (current ratio, ROA, ROE, margins, D/E)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr, report='half-year')

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share  shares  fcf  \
# 0 2014-09-01     6.636953 2014-06-30    920.0  0.0      1.712121   792.0  0.0
# 1 2014-09-08     6.356215 2014-06-30    920.0  0.0      1.712121   792.0  0.0
# 2 2014-09-15     6.226644 2014-06-30    920.0  0.0      1.712121   792.0  0.0
# 3 2014-09-22     5.852325 2014-06-30    920.0  0.0      1.712121   792.0  0.0
# 4 2014-09-29     5.981897 2014-06-30    920.0  0.0      1.712121   792.0  0.0
#
#    fcf_per_share   cash  ...  equity_ratio  debt_ratio  acc_rec_ratio  \
# 0            0.0  114.0  ...      0.535968    0.464032            0.0
# 1            0.0  114.0  ...      0.535968    0.464032            0.0
# 2            0.0  114.0  ...      0.535968    0.464032            0.0
# 3            0.0  114.0  ...      0.535968    0.464032            0.0
# 4            0.0  114.0  ...      0.535968    0.464032            0.0
#
#    acc_pay_ratio  cash_turnover  inventory_turnover  gross_profit_margin  \
# 0            0.0            0.0                 0.0             0.355435
# 1            0.0            0.0                 0.0             0.355435
# 2            0.0            0.0                 0.0             0.355435
# 3            0.0            0.0                 0.0             0.355435
# 4            0.0            0.0                 0.0             0.355435
#
#    net_profit_margin  roa  roe
# 0           0.054348  0.0  0.0
# 1           0.054348  0.0  0.0
# 2           0.054348  0.0  0.0
# 3           0.054348  0.0  0.0
# 4           0.054348  0.0  0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr, report='half-year')
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue  eps  bv_per_share  shares  fcf  \
# 0 2014-09-01     6.636953 2014-06-30    920.0  0.0      1.712121   792.0  0.0
# 1 2014-09-08     6.356215 2014-06-30    920.0  0.0      1.712121   792.0  0.0
# 2 2014-09-15     6.226644 2014-06-30    920.0  0.0      1.712121   792.0  0.0
# 3 2014-09-22     5.852325 2014-06-30    920.0  0.0      1.712121   792.0  0.0
# 4 2014-09-29     5.981897 2014-06-30    920.0  0.0      1.712121   792.0  0.0
#
#    fcf_per_share   cash  ...  inventory_turnover  gross_profit_margin  \
# 0            0.0  114.0  ...                 0.0             0.355435
# 1            0.0  114.0  ...                 0.0             0.355435
# 2            0.0  114.0  ...                 0.0             0.355435
# 3            0.0  114.0  ...                 0.0             0.355435
# 4            0.0  114.0  ...                 0.0             0.355435
#
#    net_profit_margin  roa  roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# 0           0.054348  0.0  0.0       inf  3.876451       inf         inf
# 1           0.054348  0.0  0.0       inf  3.712480       inf         inf
# 2           0.054348  0.0  0.0       inf  3.636801       inf         inf
# 3           0.054348  0.0  0.0       inf  3.418172       inf         inf
# 4           0.054348  0.0  0.0       inf  3.493851       inf         inf
#
#    pfcf_ratio
# 0         inf
# 1         inf
# 2         inf
# 3         inf
# 4         inf
#
# [5 rows x 32 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate   NaN
# share_price     NaN
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.983995 -0.061636  0.208895  0.258474    0.107762
# roe             0.983995  1.000000  0.001864  0.245199  0.290556    0.155546
# pe_ratio       -0.061636  0.001864  1.000000  0.383024  0.290993    0.293882
# pb_ratio        0.208895  0.245199  0.383024  1.000000  0.932394    0.896922
# ps_ratio        0.258474  0.290556  0.290993  0.932394  1.000000    0.966815
# ev_revenue      0.107762  0.155546  0.293882  0.896922  0.966815    1.000000
# debt_to_equity -0.608072 -0.575767  0.099706 -0.062177 -0.212330    0.021272
# current_ratio   0.569891  0.488255 -0.128166  0.008474 -0.050720   -0.188961
#
#                 debt_to_equity  current_ratio
# roa                  -0.608072       0.569891
# roe                  -0.575767       0.488255
# pe_ratio              0.099706      -0.128166
# pb_ratio             -0.062177       0.008474
# ps_ratio             -0.212330      -0.050720
# ev_revenue            0.021272      -0.188961
# debt_to_equity        1.000000      -0.311463
# current_ratio        -0.311463       1.000000

# %%
final_df = utils.get_value_stock_target_prices(
    input_df=merged_nat_curr,
    min_pct=0.2,
    max_pct=0.5,
    owned_shares=owned_shares
)
