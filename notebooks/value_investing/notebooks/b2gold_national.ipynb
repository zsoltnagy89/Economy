# %%
import pandas as pd
import matplotlib.pyplot as plt

import yfinance as yf
import datetime

# import from utils.ipynb
import ipynb.fs.full.utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = False
X=10
currency_pair = 'CAD=X'
numbers_in_currency = 'USD'
share_name = 'BTO.TO'

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../csv_files/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../csv_files/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2009-06-30        8    -8            -1          -3     5        3
# 1 2009-09-30        9    -9             1          -2     9        5
# 2 2009-12-31        4    -5            -1         -17     3        5
# 3 2010-03-31       17   -16             1          -4    22       11
# 4 2010-06-30       23   -19             5          -8    14       10
#
#    inventory  curr_assets  goodwill  ...  total_assets  acc_pay  \
# 0          7           16         0  ...           224        0
# 1          8           26         0  ...           241        0
# 2         10           23         0  ...           247        0
# 3         12           47         0  ...           283        0
# 4         18           44         0  ...           285        0
#
#    short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 0                0             0         16               0          39
# 1                0             0         13               0          31
# 2                1             0         12               9          48
# 3                0            15         30               0          58
# 4                0            17         33               0          60
#
#    cash_from_operating_activities  capex  shares
# 0                              -4    -14   282.5
# 1                               1      8   282.5
# 2                              -7    -42   282.5
# 3                               1    -15   337.6
# 4                              -1     -9   337.6
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 54 2022-12-31 2023-02-11  1071.0      592  -332           261         176
# 55 2023-03-31 2023-04-21  1237.4      474  -260           214         102
# 56 2023-06-30 2023-07-21  1237.4      471  -281           190          92
# 57 2023-09-30 2023-10-21  1237.4      478  -307           171         -35
# 58 2023-12-31 2024-02-11  1237.4      512  -306           206        -117
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 54   652        0        332  ...                  0          3681        0
# 55   674        0        350  ...                  0          3768        0
# 56   506        0        339  ...                  0          4931        0
# 57   310        0        344  ...                  0          4852        0
# 58   307        0        346  ...                  0          4875        0
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 54                0            16        234              13         673
# 55                0            15        268              11         721
# 56                0            17        319              15         909
# 57                0            15        325              12         895
# 58                0            16        313             152        1064
#
#     cash_from_operating_activities  capex
# 54                             270   -113
# 55                             204   -111
# 56                             195   -205
# 57                             110   -226
# 58                             205   -269
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
data['usd_nat_currency'] = utils.daily_price(
    ticker=currency_pair,
    end=data['date'],
    days_earlier=90
    )

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 54 2022-12-31 2023-02-11  1071.0      592  -332           261         176
# 55 2023-03-31 2023-04-21  1237.4      474  -260           214         102
# 56 2023-06-30 2023-07-21  1237.4      471  -281           190          92
# 57 2023-09-30 2023-10-21  1237.4      478  -307           171         -35
# 58 2023-12-31 2024-02-11  1237.4      512  -306           206        -117
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 54   652        0        332  ...          3681        0                0
# 55   674        0        350  ...          3768        0                0
# 56   506        0        339  ...          4931        0                0
# 57   310        0        344  ...          4852        0                0
# 58   307        0        346  ...          4875        0                0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 54            16        234              13         673
# 55            15        268              11         721
# 56            17        319              15         909
# 57            15        325              12         895
# 58            16        313             152        1064
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 54                             270   -113          1.357405
# 55                             204   -111          1.352063
# 56                             195   -205          1.343352
# 57                             110   -226          1.341033
# 58                             205   -269          1.361617
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date  shares     revenue        cogs  gross_profit  \
# 54 2022-12-31 2023-02-11  1071.0  803.583810 -450.658488    354.282727
# 55 2023-03-31 2023-04-21  1237.4  640.877699 -351.536290    289.341408
# 56 2023-06-30 2023-07-21  1237.4  632.718662 -377.481834    255.236827
# 57 2023-09-30 2023-10-21  1237.4  641.013737 -411.697107    229.316630
# 58 2023-12-31 2024-02-11  1237.4  697.148103 -416.654921    280.493182
#
#     net_profit        cash  acc_rec   inventory  ...  total_assets  acc_pay  \
# 54  238.903295  885.028115      0.0  450.658488  ...   4996.608117      0.0
# 55  137.910391  911.290230      0.0  473.221929  ...   5094.572086      0.0
# 56  123.588359  679.735972      0.0  455.396234  ...   6624.067349      0.0
# 57  -46.936152  415.720206      0.0  461.315326  ...   6506.691743      0.0
# 58 -159.309235  418.016538      0.0  471.119617  ...   6637.884772      0.0
#
#     short_term_debt  current_debt   curr_liab  long_term_debt   total_liab  \
# 54              0.0     21.718481  317.632790       17.646266   913.533622
# 55              0.0     20.280940  362.352792       14.872689   974.837175
# 56              0.0     22.836979  428.529200       20.150276  1221.106717
# 57              0.0     20.115494  435.835700       16.092395  1200.224466
# 58              0.0     21.785878  426.186243      206.965843  1448.760902
#
#     cash_from_operating_activities       capex  usd_nat_currency
# 54                      366.499373 -153.386775          1.357405
# 55                      275.820782 -150.078955          1.352063
# 56                      261.953586 -275.387103          1.343352
# 57                      147.513622 -303.073441          1.341033
# 58                      279.131565 -366.275078          1.361617
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr)

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr)

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date   revenue       eps  bv_per_share  \
# 0 2009-07-27     0.617709 2009-06-30  9.338312 -0.049584      0.764419
# 1 2009-08-03     0.634633 2009-06-30  9.338312 -0.049584      0.764419
# 2 2009-08-10     0.592324 2009-06-30  9.338312 -0.049584      0.764419
# 3 2009-08-17     0.592324 2009-06-30  9.338312 -0.049584      0.764419
# 4 2009-08-24     0.600786 2009-06-30  9.338312 -0.049584      0.764419
#
#    shares        fcf  fcf_per_share      cash  ...  equity_ratio  debt_ratio  \
# 0   282.5  46.691562        0.16528  5.836445  ...      0.825893    0.174107
# 1   282.5  46.691562        0.16528  5.836445  ...      0.825893    0.174107
# 2   282.5  46.691562        0.16528  5.836445  ...      0.825893    0.174107
# 3   282.5  46.691562        0.16528  5.836445  ...      0.825893    0.174107
# 4   282.5  46.691562        0.16528  5.836445  ...      0.825893    0.174107
#
#    acc_rec_ratio  acc_pay_ratio  cash_turnover  inventory_turnover  \
# 0      10.666667            inf            6.4            4.571429
# 1      10.666667            inf            6.4            4.571429
# 2      10.666667            inf            6.4            4.571429
# 3      10.666667            inf            6.4            4.571429
# 4      10.666667            inf            6.4            4.571429
#
#    gross_profit_margin  net_profit_margin       roa       roe
# 0               -0.125             -0.375 -0.053571 -0.064865
# 1               -0.125             -0.375 -0.053571 -0.064865
# 2               -0.125             -0.375 -0.053571 -0.064865
# 3               -0.125             -0.375 -0.053571 -0.064865
# 4               -0.125             -0.375 -0.053571 -0.064865
#
# [5 rows x 25 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date   revenue       eps  bv_per_share  \
# 0 2009-07-27     0.617709 2009-06-30  9.338312 -0.049584      0.764419
# 1 2009-08-03     0.634633 2009-06-30  9.338312 -0.049584      0.764419
# 2 2009-08-10     0.592324 2009-06-30  9.338312 -0.049584      0.764419
# 3 2009-08-17     0.592324 2009-06-30  9.338312 -0.049584      0.764419
# 4 2009-08-24     0.600786 2009-06-30  9.338312 -0.049584      0.764419
#
#    shares        fcf  fcf_per_share      cash  ...  inventory_turnover  \
# 0   282.5  46.691562        0.16528  5.836445  ...            4.571429
# 1   282.5  46.691562        0.16528  5.836445  ...            4.571429
# 2   282.5  46.691562        0.16528  5.836445  ...            4.571429
# 3   282.5  46.691562        0.16528  5.836445  ...            4.571429
# 4   282.5  46.691562        0.16528  5.836445  ...            4.571429
#
#    gross_profit_margin  net_profit_margin       roa       roe   pe_ratio  \
# 0               -0.125             -0.375 -0.053571 -0.064865 -12.457847
# 1               -0.125             -0.375 -0.053571 -0.064865 -12.799153
# 2               -0.125             -0.375 -0.053571 -0.064865 -11.945880
# 3               -0.125             -0.375 -0.053571 -0.064865 -11.945880
# 4               -0.125             -0.375 -0.053571 -0.064865 -12.116535
#
#    pb_ratio  ps_ratio  ev_revenue  pfcf_ratio
# 0  0.808077  4.671693    5.734193    3.737354
# 1  0.830215  4.799683    5.862183    3.839746
# 2  0.774868  4.479705    5.542205    3.583764
# 3  0.774868  4.479705    5.542205    3.583764
# 4  0.785937  4.543701    5.606201    3.634961
#
# [5 rows x 30 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate    0.454121
# share_price      1.000000
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)
# Out:
# pe_ratio diagram is missing due to error.

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.996024  0.104134  0.459238 -0.191974   -0.295307
# roe             0.996024  1.000000  0.106744  0.443995 -0.177460   -0.274409
# pe_ratio        0.104134  0.106744  1.000000  0.134025 -0.068708   -0.067099
# pb_ratio        0.459238  0.443995  0.134025  1.000000  0.331351    0.203311
# ps_ratio       -0.191974 -0.177460 -0.068708  0.331351  1.000000    0.979725
# ev_revenue     -0.295307 -0.274409 -0.067099  0.203311  0.979725    1.000000
# debt_to_equity -0.206925 -0.166472  0.153897 -0.274032 -0.242695   -0.077886
# current_ratio   0.198433  0.160676  0.017744  0.340444  0.026676   -0.085847
#
#                 debt_to_equity  current_ratio
# roa                  -0.206925       0.198433
# roe                  -0.166472       0.160676
# pe_ratio              0.153897       0.017744
# pb_ratio             -0.274032       0.340444
# ps_ratio             -0.242695       0.026676
# ev_revenue           -0.077886      -0.085847
# debt_to_equity        1.000000      -0.508788
# current_ratio        -0.508788       1.000000

# %%
# plot value parameters in time and identify similar events
utils.get_historical_analouges(
    input_df=merged_nat_curr,
    ticker_all_price=ticker_all_price,
    share_name=share_name,
    tolerance=0.2,
    owned_shares=owned_shares
    )
# Out:
# 0 timestemos have been found!
