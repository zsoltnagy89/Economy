# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import yfinance as yf
import datetime

# import from utils.ipynb
import ipynb.fs.full.utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = True
X=10
currency_pair = 'USD=X'
numbers_in_currency = 'USD'
share_name = 'IFF'

# %% [markdown]
# # 1.1 Calculate Share numbers from total distributed dividend (CFS) and dividend amount

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../csv_files/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../csv_files/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2013-12-31      725  -412           314          62   406      524
# 1 2014-03-31      770  -429           341         107   269      575
# 2 2014-06-30      788  -436           353         110   327      583
# 3 2014-09-30      774  -434           340         107   405      563
# 4 2014-12-31      756  -428           328          90   479      494
#
#    inventory  curr_assets  goodwill  ...  total_assets  acc_pay  \
# 0        534         1653       666  ...          3332      227
# 1        552         1570       676  ...          3321      209
# 2        555         1644       675  ...          3401      195
# 3        556         1713       675  ...          3477      207
# 4        569         1711       675  ...          3495      216
#
#    short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 0                0             0        561             933        1869
# 1                0             2        484             932        1805
# 2                0             3        468             933        1802
# 3                0            10        517             934        1837
# 4                0             8        518             934        1976
#
#    cash_from_operating_activities  capex  shares
# 0                             150    -48    81.9
# 1                              35    -34    81.5
# 2                             119    -26    81.5
# 3                             164    -38    81.5
# 4                             201    -45    81.5
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 36 2022-12-31 2023-02-11   255.0     2844 -1975           869         -24
# 37 2023-03-31 2023-04-21   255.0     3027 -2063           964          -8
# 38 2023-06-30 2023-07-21   255.0     2929 -1996           933          27
# 39 2023-09-30 2023-10-21   255.0     2820 -1896           924          27
# 40 2023-12-31 2024-02-11   255.0     2703 -1843           860       -2609
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 36   483     1818       3151  ...               9082         35504     1418
# 37   590     1899       2946  ...               8968         35470     1197
# 38   638     1887       2790  ...               8813         34459     1227
# 39   629     1831       2549  ...               8381         33395     1112
# 40   709     1726       2477  ...              18992         30978        0
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 36              193           404       3472           10373       17849
# 37              589          1482       4585            9220       17712
# 38              159          1203       3630            9208       16836
# 39                0          1142       3420            9159       16417
# 40                0           885       3758            9186       16336
#
#     cash_from_operating_activities  capex
# 36                             208   -160
# 37                             127   -175
# 38                             248   -115
# 39                             420   -100
# 40                             644   -113
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
if currency_pair != 'USD=X':
    data['usd_nat_currency'] = utils.daily_price(
        ticker=currency_pair,
        end=data['date'],
        days_earlier=90
        )
else:
    data['usd_nat_currency'] = [1 for x in range(len(data))]

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 36 2022-12-31 2023-02-11   255.0     2844 -1975           869         -24
# 37 2023-03-31 2023-04-21   255.0     3027 -2063           964          -8
# 38 2023-06-30 2023-07-21   255.0     2929 -1996           933          27
# 39 2023-09-30 2023-10-21   255.0     2820 -1896           924          27
# 40 2023-12-31 2024-02-11   255.0     2703 -1843           860       -2609
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 36   483     1818       3151  ...         35504     1418              193
# 37   590     1899       2946  ...         35470     1197              589
# 38   638     1887       2790  ...         34459     1227              159
# 39   629     1831       2549  ...         33395     1112                0
# 40   709     1726       2477  ...         30978        0                0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 36           404       3472           10373       17849
# 37          1482       4585            9220       17712
# 38          1203       3630            9208       16836
# 39          1142       3420            9159       16417
# 40           885       3758            9186       16336
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 36                             208   -160                 1
# 37                             127   -175                 1
# 38                             248   -115                 1
# 39                             420   -100                 1
# 40                             644   -113                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date  shares  revenue    cogs  gross_profit  net_profit  \
# 36 2022-12-31 2023-02-11   255.0   2844.0 -1975.0         869.0       -24.0
# 37 2023-03-31 2023-04-21   255.0   3027.0 -2063.0         964.0        -8.0
# 38 2023-06-30 2023-07-21   255.0   2929.0 -1996.0         933.0        27.0
# 39 2023-09-30 2023-10-21   255.0   2820.0 -1896.0         924.0        27.0
# 40 2023-12-31 2024-02-11   255.0   2703.0 -1843.0         860.0     -2609.0
#
#      cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 36  483.0   1818.0     3151.0  ...       35504.0   1418.0            193.0
# 37  590.0   1899.0     2946.0  ...       35470.0   1197.0            589.0
# 38  638.0   1887.0     2790.0  ...       34459.0   1227.0            159.0
# 39  629.0   1831.0     2549.0  ...       33395.0   1112.0              0.0
# 40  709.0   1726.0     2477.0  ...       30978.0      0.0              0.0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 36         404.0     3472.0         10373.0     17849.0
# 37        1482.0     4585.0          9220.0     17712.0
# 38        1203.0     3630.0          9208.0     16836.0
# 39        1142.0     3420.0          9159.0     16417.0
# 40         885.0     3758.0          9186.0     16336.0
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 36                           208.0 -160.0                 1
# 37                           127.0 -175.0                 1
# 38                           248.0 -115.0                 1
# 39                           420.0 -100.0                 1
# 40                           644.0 -113.0                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr)

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %% [markdown]
# ## Calculate performance parameters (current ratio, ROA, ROE, margins, D/E)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr)

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue       eps  bv_per_share  shares  \
# 0 2014-02-17    72.034653 2013-12-31    725.0  3.028083     17.863248    81.9
# 1 2014-02-24    73.926346 2013-12-31    725.0  3.028083     17.863248    81.9
# 2 2014-03-03    75.116524 2013-12-31    725.0  3.028083     17.863248    81.9
# 3 2014-03-10    73.177536 2013-12-31    725.0  3.028083     17.863248    81.9
# 4 2014-03-17    73.910553 2013-12-31    725.0  3.028083     17.863248    81.9
#
#      fcf  fcf_per_share   cash  ...  equity_ratio  debt_ratio  acc_rec_ratio  \
# 0  792.0        9.67033  406.0  ...      0.439076    0.560924       5.534351
# 1  792.0        9.67033  406.0  ...      0.439076    0.560924       5.534351
# 2  792.0        9.67033  406.0  ...      0.439076    0.560924       5.534351
# 3  792.0        9.67033  406.0  ...      0.439076    0.560924       5.534351
# 4  792.0        9.67033  406.0  ...      0.439076    0.560924       5.534351
#
#    acc_pay_ratio  cash_turnover  inventory_turnover  gross_profit_margin  \
# 0       7.259912       7.142857            3.086142             0.433103
# 1       7.259912       7.142857            3.086142             0.433103
# 2       7.259912       7.142857            3.086142             0.433103
# 3       7.259912       7.142857            3.086142             0.433103
# 4       7.259912       7.142857            3.086142             0.433103
#
#    net_profit_margin      roa       roe
# 0           0.085517  0.07443  0.169515
# 1           0.085517  0.07443  0.169515
# 2           0.085517  0.07443  0.169515
# 3           0.085517  0.07443  0.169515
# 4           0.085517  0.07443  0.169515
#
# [5 rows x 25 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue       eps  bv_per_share  shares  \
# 0 2014-02-17    72.034653 2013-12-31    725.0  3.028083     17.863248    81.9
# 1 2014-02-24    73.926346 2013-12-31    725.0  3.028083     17.863248    81.9
# 2 2014-03-03    75.116524 2013-12-31    725.0  3.028083     17.863248    81.9
# 3 2014-03-10    73.177536 2013-12-31    725.0  3.028083     17.863248    81.9
# 4 2014-03-17    73.910553 2013-12-31    725.0  3.028083     17.863248    81.9
#
#      fcf  fcf_per_share   cash  ...  inventory_turnover  gross_profit_margin  \
# 0  792.0        9.67033  406.0  ...            3.086142             0.433103
# 1  792.0        9.67033  406.0  ...            3.086142             0.433103
# 2  792.0        9.67033  406.0  ...            3.086142             0.433103
# 3  792.0        9.67033  406.0  ...            3.086142             0.433103
# 4  792.0        9.67033  406.0  ...            3.086142             0.433103
#
#    net_profit_margin      roa       roe   pe_ratio  pb_ratio  ps_ratio  \
# 0           0.085517  0.07443  0.169515  23.788863  4.032562  2.034358
# 1           0.085517  0.07443  0.169515  24.413580  4.138461  2.087782
# 2           0.085517  0.07443  0.169515  24.806626  4.205088  2.121394
# 3           0.085517  0.07443  0.169515  24.166291  4.096541  2.066635
# 4           0.085517  0.07443  0.169515  24.408364  4.137576  2.087336
#
#    ev_revenue  pfcf_ratio
# 0    2.538841    7.449038
# 1    2.592265    7.644656
# 2    2.625877    7.767731
# 3    2.571117    7.567222
# 4    2.591819    7.643023
#
# [5 rows x 30 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate   NaN
# share_price     NaN
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.994468  0.073727  0.668165  0.288310   -0.315755
# roe             0.994468  1.000000  0.073713  0.731398  0.323530   -0.315365
# pe_ratio        0.073727  0.073713  1.000000  0.077463  0.096196   -0.021491
# pb_ratio        0.668165  0.731398  0.077463  1.000000  0.457878   -0.334024
# ps_ratio        0.288310  0.323530  0.096196  0.457878  1.000000    0.573616
# ev_revenue     -0.315755 -0.315365 -0.021491 -0.334024  0.573616    1.000000
# debt_to_equity  0.490007  0.570978  0.045104  0.881769  0.464524   -0.233637
# current_ratio   0.220826  0.215872  0.060288  0.181588  0.212548   -0.360589
#
#                 debt_to_equity  current_ratio
# roa                   0.490007       0.220826
# roe                   0.570978       0.215872
# pe_ratio              0.045104       0.060288
# pb_ratio              0.881769       0.181588
# ps_ratio              0.464524       0.212548
# ev_revenue           -0.233637      -0.360589
# debt_to_equity        1.000000       0.229103
# current_ratio         0.229103       1.000000

# %%
# plot value parameters in time and identify similar events
utils.get_historical_analouges(
    input_df=merged_nat_curr,
    ticker_all_price=ticker_all_price,
    share_name=share_name,
    tolerance=0.2,
    owned_shares=owned_shares
    )
# Out:
# 0 timestemos have been found!
