# %%
import pandas as pd
import matplotlib.pyplot as plt

import yfinance as yf
import datetime

# import from utils.ipynb
import ipynb.fs.full.utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = False
X=10
currency_pair = 'NOK=X'
numbers_in_currency = 'USD'
share_name = 'DNO.OL'

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../csv_files/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../csv_files/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2000-03-31       17    -2            16           6     9        0
# 1 2000-06-30       18    -2            16           2     6        0
# 2 2000-09-30       18    -3            15          -1    24        0
# 3 2000-12-31       22    -4            18          -1    10        0
# 4 2001-03-31       32    -7            26           4     6        0
#
#    inventory  curr_assets  goodwill  ...  total_assets  acc_pay  \
# 0          0           32        13  ...           144        0
# 1          0           20        12  ...           143        0
# 2          0           42        11  ...           171        0
# 3          0           39        15  ...           182        0
# 4          0           34        14  ...           211        0
#
#    short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 0                0             4         28              13          69
# 1                0             0         24              13          64
# 2                0            19         55               0          82
# 3                0            12         37              17          91
# 4                0            11         57              26         119
#
#    cash_from_operating_activities  capex  shares
# 0                               1      0    50.2
# 1                              10      0    50.2
# 2                               9      0    50.2
# 3                              -4      0    50.2
# 4                              24      0    51.6
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 91 2022-12-31 2023-02-11  986.97      338  -146           193          43
# 92 2023-03-31 2023-04-21  975.00      269  -105           164          87
# 93 2023-06-30 2023-07-21  975.00       58   -57             2         -19
# 94 2023-09-30 2023-10-21  975.00      141   -88            54         -55
# 95 2023-12-31 2024-02-11  975.00      199  -116            84           4
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 91   932      312         47  ...                 97          2803       72
# 92   887      416         54  ...                109          2738       52
# 93   729      422         67  ...                124          2640       90
# 94   708      152         74  ...                160          2583       91
# 95   719      265         78  ...                202          2638        0
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 91                0            15        445             546        1434
# 92                0            39        400             521        1373
# 93                0           170        444             390        1324
# 94                0           170        415             391        1338
# 95                0           166        415             392        1404
#
#     cash_from_operating_activities  capex
# 91                             245    -76
# 92                             107    -57
# 93                             -68    -45
# 94                              53    -26
# 95                             102    -36
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
data['usd_nat_currency'] = utils.daily_price(
    ticker=currency_pair,
    end=data['date'],
    days_earlier=90
    )

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
# NOK=X: Data doesn't exist for startDate = 946684800, endDate = 954457200
# /Users/zsolt.nagy/Desktop/projects/Economy/notebooks/value_investing/notebooks/utils.ipynb:68: RuntimeWarning: Mean of empty slice.
#   "    return filtered"
# /Users/zsolt.nagy/Desktop/projects/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# NOK=X: Data doesn't exist for startDate = 954543600, endDate = 962319600
# /Users/zsolt.nagy/Desktop/projects/Economy/notebooks/value_investing/notebooks/utils.ipynb:68: RuntimeWarning: Mean of empty slice.
#   "    return filtered"
# /Users/zsolt.nagy/Desktop/projects/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# NOK=X: Data doesn't exist for startDate = 962492400, endDate = 970268400
# /Users/zsolt.nagy/Desktop/projects/Economy/notebooks/value_investing/notebooks/utils.ipynb:68: RuntimeWarning: Mean of empty slice.
#   "    return filtered"
# /Users/zsolt.nagy/Desktop/projects/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# NOK=X: Data doesn't exist for startDate = 970441200, endDate = 978220800
# /Users/zsolt.nagy/Desktop/projects/Economy/notebooks/value_investing/notebooks/utils.ipynb:68: RuntimeWarning: Mean of empty slice.
#   "    return filtered"
# /Users/zsolt.nagy/Desktop/projects/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# NOK=X: Data doesn't exist for startDate = 978220800, endDate = 985993200
# /Users/zsolt.nagy/Desktop/projects/Economy/notebooks/value_investing/notebooks/utils.ipynb:68: RuntimeWarning: Mean of empty slice.
#   "    return filtered"
# /Users/zsolt.nagy/Desktop/projects/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# NOK=X: Data doesn't exist for startDate = 986079600, endDate = 993855600
# /Users/zsolt.nagy/Desktop/projects/Economy/notebooks/value_investing/notebooks/utils.ipynb:68: RuntimeWarning: Mean of empty slice.
#   "    return filtered"
# /Users/zsolt.nagy/Desktop/projects/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# NOK=X: No price data found, symbol may be delisted (1d 2003-07-02 00:00:00 -> 2003-09-30 00:00:00)
# /Users/zsolt.nagy/Desktop/projects/Economy/notebooks/value_investing/notebooks/utils.ipynb:68: RuntimeWarning: Mean of empty slice.
#   "    return filtered"
# /Users/zsolt.nagy/Desktop/projects/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 91 2022-12-31 2023-02-11  986.97      338  -146           193          43
# 92 2023-03-31 2023-04-21  975.00      269  -105           164          87
# 93 2023-06-30 2023-07-21  975.00       58   -57             2         -19
# 94 2023-09-30 2023-10-21  975.00      141   -88            54         -55
# 95 2023-12-31 2024-02-11  975.00      199  -116            84           4
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 91   932      312         47  ...          2803       72                0
# 92   887      416         54  ...          2738       52                0
# 93   729      422         67  ...          2640       90                0
# 94   708      152         74  ...          2583       91                0
# 95   719      265         78  ...          2638        0                0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 91            15        445             546        1434
# 92            39        400             521        1373
# 93           170        444             390        1324
# 94           170        415             391        1338
# 95           166        415             392        1404
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 91                             245    -76         10.186402
# 92                             107    -57         10.221379
# 93                             -68    -45         10.699984
# 94                              53    -26         10.483742
# 95                             102    -36         10.821103
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date  shares      revenue         cogs  gross_profit  \
# 91 2022-12-31 2023-02-11  986.97  3443.003771 -1487.214647   1965.975526
# 92 2023-03-31 2023-04-21  975.00  2749.550846 -1073.244754   1676.306092
# 93 2023-06-30 2023-07-21  975.00   620.599055  -609.899071     21.399967
# 94 2023-09-30 2023-10-21  975.00  1478.207628  -922.569299    566.122070
# 95 2023-12-31 2024-02-11  975.00  2153.399487 -1255.247942    908.972648
#
#     net_profit         cash      acc_rec   inventory  ...  total_assets  \
# 91  438.015273  9493.726375  3178.157327  478.760879  ...  28552.483937
# 92  889.259939  9066.362827  4252.093502  551.954445  ...  27986.134633
# 93 -203.299690  7800.288118  4515.393122  716.898908  ...  28247.956971
# 94 -576.605812  7422.489364  1593.528790  775.796911  ...  27079.505687
# 95   43.284412  7780.373021  2867.592282  844.046030  ...  28546.069580
#
#        acc_pay  short_term_debt  current_debt    curr_liab  long_term_debt  \
# 91  733.420922              0.0    152.796025  4532.948752     5561.775323
# 92  531.511688              0.0    398.633766  4088.551444     5325.338256
# 93  962.998533              0.0   1818.997229  4750.792763     4172.993643
# 94  954.020526              0.0   1782.236147  4350.752946     4099.143137
# 95    0.000000              0.0   1796.303090  4490.757724     4241.872356
#
#       total_liab  cash_from_operating_activities       capex  usd_nat_currency
# 91  14607.300023                     2495.668414 -774.166528         10.186402
# 92  14033.952831                     1093.687511 -582.618581         10.221379
# 93  14166.778420                     -727.598892 -481.499267         10.699984
# 94  14027.246848                      555.638328 -272.577293         10.483742
# 95  15192.828541                     1103.752501 -389.559706         10.821103
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr)

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr)

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data
# ## Pull historical share prices

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date     revenue       eps  bv_per_share  \
# 0 2001-10-22     0.428342 2001-09-30  321.246655  3.458728     17.812449
# 1 2001-10-29     0.459410 2001-09-30  321.246655  3.458728     17.812449
# 2 2001-11-05     0.510639 2001-09-30  321.246655  3.458728     17.812449
# 3 2001-11-12     0.469656 2001-09-30  321.246655  3.458728     17.812449
# 4 2001-11-19     0.483207 2001-09-30  321.246655  3.458728     17.812449
#
#    shares         fcf  fcf_per_share        cash  ...  equity_ratio  \
# 0    51.6  678.187383      13.143166  223.087955  ...       0.39313
# 1    51.6  678.187383      13.143166  223.087955  ...       0.39313
# 2    51.6  678.187383      13.143166  223.087955  ...       0.39313
# 3    51.6  678.187383      13.143166  223.087955  ...       0.39313
# 4    51.6  678.187383      13.143166  223.087955  ...       0.39313
#
#    debt_ratio  acc_rec_ratio  acc_pay_ratio  cash_turnover  \
# 0     0.60687            inf            inf           5.76
# 1     0.60687            inf            inf           5.76
# 2     0.60687            inf            inf           5.76
# 3     0.60687            inf            inf           5.76
# 4     0.60687            inf            inf           5.76
#
#    inventory_turnover  gross_profit_margin  net_profit_margin       roa  \
# 0                 inf             0.833333           0.138889  0.076336
# 1                 inf             0.833333           0.138889  0.076336
# 2                 inf             0.833333           0.138889  0.076336
# 3                 inf             0.833333           0.138889  0.076336
# 4                 inf             0.833333           0.138889  0.076336
#
#         roe
# 0  0.194175
# 1  0.194175
# 2  0.194175
# 3  0.194175
# 4  0.194175
#
# [5 rows x 25 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date     revenue       eps  bv_per_share  \
# 0 2001-10-22     0.428342 2001-09-30  321.246655  3.458728     17.812449
# 1 2001-10-29     0.459410 2001-09-30  321.246655  3.458728     17.812449
# 2 2001-11-05     0.510639 2001-09-30  321.246655  3.458728     17.812449
# 3 2001-11-12     0.469656 2001-09-30  321.246655  3.458728     17.812449
# 4 2001-11-19     0.483207 2001-09-30  321.246655  3.458728     17.812449
#
#    shares         fcf  fcf_per_share        cash  ...  inventory_turnover  \
# 0    51.6  678.187383      13.143166  223.087955  ...                 inf
# 1    51.6  678.187383      13.143166  223.087955  ...                 inf
# 2    51.6  678.187383      13.143166  223.087955  ...                 inf
# 3    51.6  678.187383      13.143166  223.087955  ...                 inf
# 4    51.6  678.187383      13.143166  223.087955  ...                 inf
#
#    gross_profit_margin  net_profit_margin       roa       roe  pe_ratio  \
# 0             0.833333           0.138889  0.076336  0.194175  0.123844
# 1             0.833333           0.138889  0.076336  0.194175  0.132826
# 2             0.833333           0.138889  0.076336  0.194175  0.147638
# 3             0.833333           0.138889  0.076336  0.194175  0.135789
# 4             0.833333           0.138889  0.076336  0.194175  0.139707
#
#    pb_ratio  ps_ratio  ev_revenue  pfcf_ratio
# 0  0.024047  0.017201    0.947756    0.032590
# 1  0.025792  0.018448    0.949004    0.034954
# 2  0.028668  0.020505    0.951061    0.038852
# 3  0.026367  0.018860    0.949415    0.035734
# 4  0.027127  0.019404    0.949959    0.036765
#
# [5 rows x 30 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate    0.099871
# share_price      1.000000
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)
# Out:
# pe_ratio diagram is missing due to error.

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.166207  0.237785  0.154113 -0.030454   -0.043657
# roe             0.166207  1.000000  0.111619  0.052286 -0.009832   -0.071099
# pe_ratio        0.237785  0.111619  1.000000  0.253436  0.184122    0.213292
# pb_ratio        0.154113  0.052286  0.253436  1.000000  0.368646    0.380781
# ps_ratio       -0.030454 -0.009832  0.184122  0.368646  1.000000    0.984176
# ev_revenue     -0.043657 -0.071099  0.213292  0.380781  0.984176    1.000000
# debt_to_equity  0.344253 -0.037199  0.334491  0.656492  0.209214    0.258481
# current_ratio  -0.135073  0.067461 -0.102746 -0.061014 -0.131609   -0.162051
#
#                 debt_to_equity  current_ratio
# roa                   0.344253      -0.135073
# roe                  -0.037199       0.067461
# pe_ratio              0.334491      -0.102746
# pb_ratio              0.656492      -0.061014
# ps_ratio              0.209214      -0.131609
# ev_revenue            0.258481      -0.162051
# debt_to_equity        1.000000      -0.196252
# current_ratio        -0.196252       1.000000

# %%
# plot value parameters in time and identify similar events
utils.get_historical_analouges(
    input_df=merged_nat_curr,
    ticker_all_price=ticker_all_price,
    share_name=share_name,
    tolerance=0.2,
    owned_shares=owned_shares
    )
# Out:
# 4 timestemos have been found!
