# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import yfinance as yf
import datetime

# import from utils.ipynb
import ipynb.fs.full.utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = False
X=10
currency_pair = 'USD=X'
numbers_in_currency = 'USD'
share_name = 'SBSW'

# %% [markdown]
# # 1.1 Calculate Share numbers from total distributed dividend (CFS) and dividend amount

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../csv_files/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../csv_files/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2012-06-30     1135  -675           460         319   143       61
# 1 2012-12-31      886  -652           233          45    34       64
# 2 2013-06-30     1007  -644           363          32   206       89
# 3 2013-12-31     1007  -608           399         145   144       94
# 4 2014-06-30      920  -594           327          50   114       75
#
#    inventory  curr_assets  goodwill  ...  total_assets  acc_pay  \
# 0        123          327         0  ...          2370     2457
# 1        106          204         0  ...          2299     2001
# 2         34          334         0  ...          2066      225
# 3         18          262         0  ...          1940      200
# 4         27          223        69  ...          2530      280
#
#    short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 0                0             0       2784             116        3568
# 1              259             0       2500             233        3427
# 2               49             0        336             345        1259
# 3               48             0        347             144        1022
# 4               52             0        415             120        1174
#
#    cash_from_operating_activities  capex  shares
# 0                             293   -189     572
# 1                              32   -190     572
# 2                             373   -157     572
# 3                             295   -145     748
# 4                             234   -126     792
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 19 2021-12-31 2022-02-11    2877     5461 -3821          1640         544
# 20 2022-06-30 2022-07-21    2831     4570 -3263          1307         803
# 21 2022-12-31 2023-02-11    2831     3878 -2945           933         359
# 22 2023-06-30 2023-07-21    2831     3326 -2728           598         427
# 23 2023-12-31 2024-02-11    2831     2846 -2689           157       -2459
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 19  1900      465       1573  ...                  0          9598      951
# 20  1673      437       1658  ...                  0          9736      883
# 21  1531      440       1549  ...                  0          9783      919
# 22  1176      425       1364  ...                  0          9569      816
# 23  1376      479       1420  ...                  0          7696      887
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 19                7             0       1290            1267        4496
# 20                7             0       1152            1275        4249
# 21                7             0       1187            1327        4441
# 22                7             0        957            1336        4260
# 23              834             0       1962            1343        4919
#
#     cash_from_operating_activities  capex
# 19                            1267   -477
# 20                             285   -399
# 21                             664   -572
# 22                             272   -596
# 23                             113   -621
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
if currency_pair != 'USD=X':
    data['usd_nat_currency'] = utils.daily_price(
        ticker=currency_pair,
        end=data['date'],
        days_earlier=90
        )
else:
    data['usd_nat_currency'] = [1 for x in range(len(data))]

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 19 2021-12-31 2022-02-11    2877     5461 -3821          1640         544
# 20 2022-06-30 2022-07-21    2831     4570 -3263          1307         803
# 21 2022-12-31 2023-02-11    2831     3878 -2945           933         359
# 22 2023-06-30 2023-07-21    2831     3326 -2728           598         427
# 23 2023-12-31 2024-02-11    2831     2846 -2689           157       -2459
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 19  1900      465       1573  ...          9598      951                7
# 20  1673      437       1658  ...          9736      883                7
# 21  1531      440       1549  ...          9783      919                7
# 22  1176      425       1364  ...          9569      816                7
# 23  1376      479       1420  ...          7696      887              834
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 19             0       1290            1267        4496
# 20             0       1152            1275        4249
# 21             0       1187            1327        4441
# 22             0        957            1336        4260
# 23             0       1962            1343        4919
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 19                            1267   -477                 1
# 20                             285   -399                 1
# 21                             664   -572                 1
# 22                             272   -596                 1
# 23                             113   -621                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date  shares  revenue    cogs  gross_profit  net_profit  \
# 19 2021-12-31 2022-02-11    2877   5461.0 -3821.0        1640.0       544.0
# 20 2022-06-30 2022-07-21    2831   4570.0 -3263.0        1307.0       803.0
# 21 2022-12-31 2023-02-11    2831   3878.0 -2945.0         933.0       359.0
# 22 2023-06-30 2023-07-21    2831   3326.0 -2728.0         598.0       427.0
# 23 2023-12-31 2024-02-11    2831   2846.0 -2689.0         157.0     -2459.0
#
#       cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 19  1900.0    465.0     1573.0  ...        9598.0    951.0              7.0
# 20  1673.0    437.0     1658.0  ...        9736.0    883.0              7.0
# 21  1531.0    440.0     1549.0  ...        9783.0    919.0              7.0
# 22  1176.0    425.0     1364.0  ...        9569.0    816.0              7.0
# 23  1376.0    479.0     1420.0  ...        7696.0    887.0            834.0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 19           0.0     1290.0          1267.0      4496.0
# 20           0.0     1152.0          1275.0      4249.0
# 21           0.0     1187.0          1327.0      4441.0
# 22           0.0      957.0          1336.0      4260.0
# 23           0.0     1962.0          1343.0      4919.0
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 19                          1267.0 -477.0                 1
# 20                           285.0 -399.0                 1
# 21                           664.0 -572.0                 1
# 22                           272.0 -596.0                 1
# 23                           113.0 -621.0                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr, report='half-year')

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %% [markdown]
# ## Calculate performance parameters (current ratio, ROA, ROE, margins, D/E)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr, report='half-year')

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue       eps  bv_per_share  shares  \
# 0 2013-02-11     4.847411 2012-12-31    886.0  0.157343     -1.972028     572
# 1 2013-02-18     3.891209 2012-12-31    886.0  0.157343     -1.972028     572
# 2 2013-02-25     3.891209 2012-12-31    886.0  0.157343     -1.972028     572
# 3 2013-03-04     4.196662 2012-12-31    886.0  0.157343     -1.972028     572
# 4 2013-03-11     3.957612 2012-12-31    886.0  0.157343     -1.972028     572
#
#      fcf  fcf_per_share  cash  ...  equity_ratio  debt_ratio  acc_rec_ratio  \
# 0  444.0       0.776224  34.0  ...     -0.490648    1.490648        27.6875
# 1  444.0       0.776224  34.0  ...     -0.490648    1.490648        27.6875
# 2  444.0       0.776224  34.0  ...     -0.490648    1.490648        27.6875
# 3  444.0       0.776224  34.0  ...     -0.490648    1.490648        27.6875
# 4  444.0       0.776224  34.0  ...     -0.490648    1.490648        27.6875
#
#    acc_pay_ratio  cash_turnover  inventory_turnover  gross_profit_margin  \
# 0       0.651674      52.117647           12.301887              0.26298
# 1       0.651674      52.117647           12.301887              0.26298
# 2       0.651674      52.117647           12.301887              0.26298
# 3       0.651674      52.117647           12.301887              0.26298
# 4       0.651674      52.117647           12.301887              0.26298
#
#    net_profit_margin       roa       roe
# 0            0.05079  0.039147 -0.079787
# 1            0.05079  0.039147 -0.079787
# 2            0.05079  0.039147 -0.079787
# 3            0.05079  0.039147 -0.079787
# 4            0.05079  0.039147 -0.079787
#
# [5 rows x 25 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr, report='half-year')
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue       eps  bv_per_share  shares  \
# 0 2013-02-11     4.847411 2012-12-31    886.0  0.157343     -1.972028     572
# 1 2013-02-18     3.891209 2012-12-31    886.0  0.157343     -1.972028     572
# 2 2013-02-25     3.891209 2012-12-31    886.0  0.157343     -1.972028     572
# 3 2013-03-04     4.196662 2012-12-31    886.0  0.157343     -1.972028     572
# 4 2013-03-11     3.957612 2012-12-31    886.0  0.157343     -1.972028     572
#
#      fcf  fcf_per_share  cash  ...  inventory_turnover  gross_profit_margin  \
# 0  444.0       0.776224  34.0  ...           12.301887              0.26298
# 1  444.0       0.776224  34.0  ...           12.301887              0.26298
# 2  444.0       0.776224  34.0  ...           12.301887              0.26298
# 3  444.0       0.776224  34.0  ...           12.301887              0.26298
# 4  444.0       0.776224  34.0  ...           12.301887              0.26298
#
#    net_profit_margin       roa       roe   pe_ratio  pb_ratio  ps_ratio  \
# 0            0.05079  0.039147 -0.079787  30.807991 -2.458084  1.564740
# 1            0.05079  0.039147 -0.079787  24.730797 -1.973202  1.256079
# 2            0.05079  0.039147 -0.079787  24.730797 -1.973202  1.256079
# 3            0.05079  0.039147 -0.079787  26.672118 -2.128095  1.354679
# 4            0.05079  0.039147 -0.079787  25.152822 -2.006874  1.277514
#
#    ev_revenue  pfcf_ratio
# 0    3.479525    6.244863
# 1    3.170864    5.012999
# 2    3.170864    5.012999
# 3    3.269464    5.406510
# 4    3.192299    5.098545
#
# [5 rows x 30 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate   NaN
# share_price     NaN
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.972152 -0.082159  0.315342  0.300911    0.147147
# roe             0.972152  1.000000 -0.040333  0.379898  0.336841    0.177417
# pe_ratio       -0.082159 -0.040333  1.000000  0.100322  0.003358   -0.062684
# pb_ratio        0.315342  0.379898  0.100322  1.000000  0.906075    0.821035
# ps_ratio        0.300911  0.336841  0.003358  0.906075  1.000000    0.953336
# ev_revenue      0.147147  0.177417 -0.062684  0.821035  0.953336    1.000000
# debt_to_equity -0.283607 -0.179446 -0.047664  0.306845  0.101747    0.077435
# current_ratio   0.482240  0.428159 -0.179156  0.180721  0.134795   -0.019403
#
#                 debt_to_equity  current_ratio
# roa                  -0.283607       0.482240
# roe                  -0.179446       0.428159
# pe_ratio             -0.047664      -0.179156
# pb_ratio              0.306845       0.180721
# ps_ratio              0.101747       0.134795
# ev_revenue            0.077435      -0.019403
# debt_to_equity        1.000000       0.083303
# current_ratio         0.083303       1.000000

# %%
# plot value parameters in time and identify similar events
utils.get_historical_analouges(
    input_df=merged_nat_curr,
    ticker_all_price=ticker_all_price,
    share_name=share_name,
    tolerance=0.2,
    owned_shares=owned_shares
    )
# Out:
# 0 timestemos have been found!
