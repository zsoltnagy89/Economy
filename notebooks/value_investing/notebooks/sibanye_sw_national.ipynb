# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import yfinance as yf
import datetime

# import from utils.ipynb
import ipynb.fs.full.utils as utils

# %% [markdown]
# # 1. Load raw input
# ## Hardcoded block

# %%
evaluate_last_X_years = True
X=10
currency_pair = 'USD=X'
numbers_in_currency = 'USD'
share_name = 'SBSW'

# %% [markdown]
# # 1.1 Calculate Share numbers from total distributed dividend (CFS) and dividend amount

# %% [markdown]
# # 1.2. Raw input statement data

# %%
route = f"../csv_files/{share_name}_data.csv"
data = pd.read_csv(route, sep=';', parse_dates=['date'])
# replace -, extend missing 0-s, fix datatype
data = utils.replace_format_input(data)

# %%
owned_shares = pd.read_csv('../csv_files/owned_stocks.csv', sep=';', parse_dates=['date'])
owned_shares = owned_shares.loc[(owned_shares['stock'] == share_name) & (owned_shares['active'] == 'yes')]

# %% [markdown]
# ## (OPTIONAL) Time Filtering - Last 7 years daat

# %%
if evaluate_last_X_years:
    data = data[data['date'] > datetime.datetime.today() - datetime.timedelta(days=X*366+93)]
    data = data.reset_index(drop=True)

data.head()
# Out:
#         date  revenue  cogs  gross_profit  net_profit  cash  acc_rec  \
# 0 2013-12-31     1007  -608           399         145   144       94
# 1 2014-06-30      920  -594           327          50   114       75
# 2 2014-12-31     1093  -729           364          89    49       86
# 3 2015-06-30      861  -663           199           7    70       86
# 4 2015-12-31      920  -622           298          35    46      105
#
#    inventory  curr_assets  goodwill  ...  total_assets  acc_pay  \
# 0         18          262         0  ...          1940      200
# 1         27          223        69  ...          2530      280
# 2         28          168        64  ...          2415      235
# 3         32          189        61  ...          2308      235
# 4         26          177        47  ...          1819      178
#
#    short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 0               48             0        347             144        1022
# 1               52             0        415             120        1174
# 2               48             0        309             226        1119
# 3               45             0        325             261        1111
# 4              128             0        344             116         854
#
#    cash_from_operating_activities  capex  shares
# 0                             295   -145     748
# 1                             234   -126     792
# 2                             140   -174     915
# 3                             116   -131     914
# 4                             157   -131     920
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Calculate date when quaterly reports could be available

# %%
data = utils.calculate_real_date(data)

# %% [markdown]
# # 2. Filter out unnecesary columns

# %%
data = utils.filter_raw_data(data)
data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 16 2021-12-31 2022-02-11    2877     5461 -3821          1640         544
# 17 2022-06-30 2022-07-21    2831     4570 -3263          1307         803
# 18 2022-12-31 2023-02-11    2831     3878 -2945           933         359
# 19 2023-06-30 2023-07-21    2831     3326 -2728           598         427
# 20 2023-12-31 2024-02-11    2831     2846 -2689           157       -2459
#
#     cash  acc_rec  inventory  ...  intangible_assets  total_assets  acc_pay  \
# 16  1900      465       1573  ...                  0          9598      951
# 17  1673      437       1658  ...                  0          9736      883
# 18  1531      440       1549  ...                  0          9783      919
# 19  1176      425       1364  ...                  0          9569      816
# 20  1376      479       1420  ...                  0          7696      887
#
#     short_term_debt  current_debt  curr_liab  long_term_debt  total_liab  \
# 16                7             0       1290            1267        4496
# 17                7             0       1152            1275        4249
# 18                7             0       1187            1327        4441
# 19                7             0        957            1336        4260
# 20              834             0       1962            1343        4919
#
#     cash_from_operating_activities  capex
# 16                            1267   -477
# 17                             285   -399
# 18                             664   -572
# 19                             272   -596
# 20                             113   -621
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Pull historical average USD national currency rates and add to the dataframe

# %%
if currency_pair != 'USD=X':
    data['usd_nat_currency'] = utils.daily_price(
        ticker=currency_pair,
        end=data['date'],
        days_earlier=90
        )
else:
    data['usd_nat_currency'] = [1 for x in range(len(data))]

# drop rows, when USD rates wasn't available
data = data[data['usd_nat_currency'].notna()]

data.tail()
# Out:
#          date  real_date  shares  revenue  cogs  gross_profit  net_profit  \
# 16 2021-12-31 2022-02-11    2877     5461 -3821          1640         544
# 17 2022-06-30 2022-07-21    2831     4570 -3263          1307         803
# 18 2022-12-31 2023-02-11    2831     3878 -2945           933         359
# 19 2023-06-30 2023-07-21    2831     3326 -2728           598         427
# 20 2023-12-31 2024-02-11    2831     2846 -2689           157       -2459
#
#     cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 16  1900      465       1573  ...          9598      951                7
# 17  1673      437       1658  ...          9736      883                7
# 18  1531      440       1549  ...          9783      919                7
# 19  1176      425       1364  ...          9569      816                7
# 20  1376      479       1420  ...          7696      887              834
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 16             0       1290            1267        4496
# 17             0       1152            1275        4249
# 18             0       1187            1327        4441
# 19             0        957            1336        4260
# 20             0       1962            1343        4919
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 16                            1267   -477                 1
# 17                             285   -399                 1
# 18                             664   -572                 1
# 19                             272   -596                 1
# 20                             113   -621                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert USD values related to IS, BS, CFS to national currency

# %%
# convert columns into national currency if necessary
if numbers_in_currency == 'USD':
    data_nat_curr = utils.convert_national_currency(input_data=data, currency=data)
else:
    data_nat_curr = data.copy()
data_nat_curr.tail()
# Out:
#          date  real_date  shares  revenue    cogs  gross_profit  net_profit  \
# 16 2021-12-31 2022-02-11    2877   5461.0 -3821.0        1640.0       544.0
# 17 2022-06-30 2022-07-21    2831   4570.0 -3263.0        1307.0       803.0
# 18 2022-12-31 2023-02-11    2831   3878.0 -2945.0         933.0       359.0
# 19 2023-06-30 2023-07-21    2831   3326.0 -2728.0         598.0       427.0
# 20 2023-12-31 2024-02-11    2831   2846.0 -2689.0         157.0     -2459.0
#
#       cash  acc_rec  inventory  ...  total_assets  acc_pay  short_term_debt  \
# 16  1900.0    465.0     1573.0  ...        9598.0    951.0              7.0
# 17  1673.0    437.0     1658.0  ...        9736.0    883.0              7.0
# 18  1531.0    440.0     1549.0  ...        9783.0    919.0              7.0
# 19  1176.0    425.0     1364.0  ...        9569.0    816.0              7.0
# 20  1376.0    479.0     1420.0  ...        7696.0    887.0            834.0
#
#     current_debt  curr_liab  long_term_debt  total_liab  \
# 16           0.0     1290.0          1267.0      4496.0
# 17           0.0     1152.0          1275.0      4249.0
# 18           0.0     1187.0          1327.0      4441.0
# 19           0.0      957.0          1336.0      4260.0
# 20           0.0     1962.0          1343.0      4919.0
#
#     cash_from_operating_activities  capex  usd_nat_currency
# 16                          1267.0 -477.0                 1
# 17                           285.0 -399.0                 1
# 18                           664.0 -572.0                 1
# 19                           272.0 -596.0                 1
# 20                           113.0 -621.0                 1
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Calculate input to Value Raios (eps, bv per share, fcf)
# ## filter out unwanted columns

# %%
filtered_nat_curr = utils.calculate_input_value_ratios(data_nat_curr, report='half-year')

# %% [markdown]
# ## Calculate input values to value ratios

# %%
ratios_nat_curr = utils.ratios_input_filter(filtered_nat_curr)

# %% [markdown]
# ## Calculate performance parameters (current ratio, ROA, ROE, margins, D/E)

# %%
ratios_nat_curr = utils.evaluate_performance(input=filtered_nat_curr, output=ratios_nat_curr, report='half-year')

# %% [markdown]
# # 4. Pull historical share prices and merge with sattement data

# %%
# pull weekly share prices and merge with the value ratios
merged_nat_curr = utils.add_share_prices_to_value_ratios(share_name, data, ratios_nat_curr)
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue       eps  bv_per_share  shares  \
# 0 2014-02-17     5.447186 2013-12-31   1007.0  0.387701      1.227273   748.0
# 1 2014-02-24     5.481400 2013-12-31   1007.0  0.387701      1.227273   748.0
# 2 2014-03-03     6.145191 2013-12-31   1007.0  0.387701      1.227273   748.0
# 3 2014-03-10     6.624215 2013-12-31   1007.0  0.387701      1.227273   748.0
# 4 2014-03-17     6.068793 2013-12-31   1007.0  0.387701      1.227273   748.0
#
#      fcf  fcf_per_share   cash  ...  equity_ratio  debt_ratio  acc_rec_ratio  \
# 0  880.0       1.176471  144.0  ...      0.473196    0.526804      21.425532
# 1  880.0       1.176471  144.0  ...      0.473196    0.526804      21.425532
# 2  880.0       1.176471  144.0  ...      0.473196    0.526804      21.425532
# 3  880.0       1.176471  144.0  ...      0.473196    0.526804      21.425532
# 4  880.0       1.176471  144.0  ...      0.473196    0.526804      21.425532
#
#    acc_pay_ratio  cash_turnover  inventory_turnover  gross_profit_margin  \
# 0           6.08      13.986111           67.555556             0.396226
# 1           6.08      13.986111           67.555556             0.396226
# 2           6.08      13.986111           67.555556             0.396226
# 3           6.08      13.986111           67.555556             0.396226
# 4           6.08      13.986111           67.555556             0.396226
#
#    net_profit_margin       roa       roe
# 0           0.143992  0.149485  0.315904
# 1           0.143992  0.149485  0.315904
# 2           0.143992  0.149485  0.315904
# 3           0.143992  0.149485  0.315904
# 4           0.143992  0.149485  0.315904
#
# [5 rows x 25 columns]

# %% [markdown]
# # Calculate price ratios (P/E, P/B, P/S, P/FCF)

# %%
merged_nat_curr = utils.price_ratios(merged_nat_curr, report='half-year')
merged_nat_curr.head()
# Out:
#    real_date  share_price       date  revenue       eps  bv_per_share  shares  \
# 0 2014-02-17     5.447186 2013-12-31   1007.0  0.387701      1.227273   748.0
# 1 2014-02-24     5.481400 2013-12-31   1007.0  0.387701      1.227273   748.0
# 2 2014-03-03     6.145191 2013-12-31   1007.0  0.387701      1.227273   748.0
# 3 2014-03-10     6.624215 2013-12-31   1007.0  0.387701      1.227273   748.0
# 4 2014-03-17     6.068793 2013-12-31   1007.0  0.387701      1.227273   748.0
#
#      fcf  fcf_per_share   cash  ...  inventory_turnover  gross_profit_margin  \
# 0  880.0       1.176471  144.0  ...           67.555556             0.396226
# 1  880.0       1.176471  144.0  ...           67.555556             0.396226
# 2  880.0       1.176471  144.0  ...           67.555556             0.396226
# 3  880.0       1.176471  144.0  ...           67.555556             0.396226
# 4  880.0       1.176471  144.0  ...           67.555556             0.396226
#
#    net_profit_margin       roa       roe   pe_ratio  pb_ratio  ps_ratio  \
# 0           0.143992  0.149485  0.315904  14.049983  4.438448  2.023086
# 1           0.143992  0.149485  0.315904  14.138233  4.466326  2.035793
# 2           0.143992  0.149485  0.315904  15.850355  5.007193  2.282325
# 3           0.143992  0.149485  0.315904  17.085907  5.397509  2.460235
# 4           0.143992  0.149485  0.315904  15.653301  4.944943  2.253951
#
#    ev_revenue  pfcf_ratio
# 0    2.459034    4.630108
# 1    2.471742    4.659190
# 2    2.718274    5.223413
# 3    2.896183    5.630583
# 4    2.689899    5.158474
#
# [5 rows x 30 columns]

# %% [markdown]
# # Calculate Dividend yield and currency-share price correlation

# %%
# get daily historical USD-national currency rates
usd_nat_curr = utils.get_historical_currency_rate(currency_pair, merged_nat_curr)

# %%
# get share prices and dividend yield data
ticker_all_price = utils.get_historical_share_dividend(share_name, merged_nat_curr)

# %%
# Pearson's correlation coefficient between share price and USD - national currency rate
utils.get_currency_share_price_correlation(share_name, usd_nat_curr, ticker_all_price)
# Out:
# currency_rate   NaN
# share_price     NaN
# Name: share_price, dtype: float64

# %% [markdown]
# # Share price and value ratios

# %%
for column in merged_nat_curr.columns[3:]:
    fig, ax1 = plt.subplots(figsize=(15, 6))

    ax2 = ax1.twinx()
    ax1.plot(merged_nat_curr['real_date'], merged_nat_curr[column], color='k', label=merged_nat_curr)
    ax2.plot(ticker_all_price.index, ticker_all_price['Close'], color='b', label=share_name)

    ax1.set_xlabel('Date')
    ax1.set_ylabel(column, color='k')
    ax2.set_ylabel('Share price (national currency)', color='b')

    plt.legend()
    plt.show()

# %%
# plot histograms of value parameters
utils.plot_histogram_value_parameters(input_df=merged_nat_curr, extra_parameters=[], owned_shares=owned_shares)

# %% [markdown]
# ## Calculate correlation between value parameters

# %%
# calulate value parameters Pearson's correlation coefficient
pd.DataFrame(merged_nat_curr, columns=['roa', 'roe', 'pe_ratio', 'pb_ratio', 'ps_ratio', 'ev_revenue', 'debt_to_equity', 'current_ratio']).corr()
# Out:
#                      roa       roe  pe_ratio  pb_ratio  ps_ratio  ev_revenue  \
# roa             1.000000  0.977883 -0.081944  0.316018  0.293157    0.128742
# roe             0.977883  1.000000 -0.043128  0.352182  0.316879    0.165694
# pe_ratio       -0.081944 -0.043128  1.000000  0.081073 -0.027659   -0.092292
# pb_ratio        0.316018  0.352182  0.081073  1.000000  0.903314    0.858324
# ps_ratio        0.293157  0.316879 -0.027659  0.903314  1.000000    0.963325
# ev_revenue      0.128742  0.165694 -0.092292  0.858324  0.963325    1.000000
# debt_to_equity -0.551680 -0.507880 -0.147685 -0.080927 -0.238774    0.000193
# current_ratio   0.472401  0.392280 -0.211358  0.022051  0.000039   -0.124870
#
#                 debt_to_equity  current_ratio
# roa                  -0.551680       0.472401
# roe                  -0.507880       0.392280
# pe_ratio             -0.147685      -0.211358
# pb_ratio             -0.080927       0.022051
# ps_ratio             -0.238774       0.000039
# ev_revenue            0.000193      -0.124870
# debt_to_equity        1.000000      -0.286894
# current_ratio        -0.286894       1.000000

# %%
# plot value parameters in time and identify similar events
utils.get_historical_analouges(
    input_df=merged_nat_curr,
    ticker_all_price=ticker_all_price,
    share_name=share_name,
    tolerance=0.2,
    owned_shares=owned_shares
    )
# Out:
# 0 timestemos have been found!
