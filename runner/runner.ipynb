# %%
import papermill as pm
from pathlib import Path

# %%
for nb in Path('../notebooks').glob('*.ipynb'):
    pm.execute_notebook(
        input_path=nb,
        output_path=nb  # Path to save executed notebook
    )
# Out:
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing: 100%|██████████| 37/37 [00:17<00:00,  2.15cell/s]
# Executing:   0%|          | 0/35 [00:00<?, ?cell/s]0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing: 100%|██████████| 35/35 [00:16<00:00,  2.13cell/s]
# Executing:   0%|          | 0/35 [00:00<?, ?cell/s]0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing: 100%|██████████| 35/35 [00:16<00:00,  2.08cell/s]
# Executing:   0%|          | 0/35 [00:00<?, ?cell/s]0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing:   3%|▎         | 1/35 [00:00<00:32,  1.06cell/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 for nb in Path('../notebooks').glob('*.ipynb'):
# ----> 2     pm.execute_notebook(
#       3         input_path=nb,
#       4         output_path=nb  # Path to save executed notebook
#       5     )
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/execute.py:119, in execute_notebook(input_path, output_path, parameters, engine_name, request_save_on_cell_execute, prepare_only, kernel_name, language, progress_bar, log_output, stdout_file, stderr_file, start_timeout, report_mode, cwd, **engine_kwargs)
#     117 # Execute the Notebook in `cwd` if it is set
#     118 with chdir(cwd):
# --> 119     nb = papermill_engines.execute_notebook_with_engine(
#     120         engine_name,
#     121         nb,
#     122         input_path=input_path,
#     123         output_path=output_path if request_save_on_cell_execute else None,
#     124         kernel_name=kernel_name,
#     125         progress_bar=progress_bar,
#     126         log_output=log_output,
#     127         start_timeout=start_timeout,
#     128         stdout_file=stdout_file,
#     129         stderr_file=stderr_file,
#     130         **engine_kwargs
#     131     )
#     133 # Check for errors first (it saves on error before raising)
#     134 raise_for_execution_errors(nb, output_path)
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/engines.py:48, in PapermillEngines.execute_notebook_with_engine(self, engine_name, nb, kernel_name, **kwargs)
#      46 def execute_notebook_with_engine(self, engine_name, nb, kernel_name, **kwargs):
#      47     """Fetch a named engine and execute the nb object against it."""
# ---> 48     return self.get_engine(engine_name).execute_notebook(nb, kernel_name, **kwargs)
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/engines.py:365, in Engine.execute_notebook(cls, nb, kernel_name, output_path, progress_bar, log_output, autosave_cell_every, **kwargs)
#     363 nb_man.notebook_start()
#     364 try:
# --> 365     cls.execute_managed_notebook(nb_man, kernel_name, log_output=log_output, **kwargs)
#     366 finally:
#     367     nb_man.cleanup_pbar()
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/engines.py:434, in NBClientEngine.execute_managed_notebook(cls, nb_man, kernel_name, log_output, stdout_file, stderr_file, start_timeout, execution_timeout, **kwargs)
#     423 # Nicely handle preprocessor arguments prioritizing values set by engine
#     424 final_kwargs = merge_kwargs(
#     425     safe_kwargs,
#     426     timeout=execution_timeout if execution_timeout else kwargs.get('timeout'),
#    (...)
#     432     stderr_file=stderr_file,
#     433 )
# --> 434 return PapermillNotebookClient(nb_man, **final_kwargs).execute()
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/clientwrap.py:45, in PapermillNotebookClient.execute(self, **kwargs)
#      43 with self.setup_kernel(**kwargs):
#      44     self.log.info("Executing notebook with kernel: %s" % self.kernel_name)
# ---> 45     self.papermill_execute_cells()
#      46     info_msg = self.wait_for_reply(self.kc.kernel_info())
#      47     self.nb.metadata['language_info'] = info_msg['content']['language_info']
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/clientwrap.py:71, in PapermillNotebookClient.papermill_execute_cells(self)
#      69 for index, cell in enumerate(self.nb.cells):
#      70     try:
# ---> 71         self.nb_man.cell_start(cell, index)
#      72         self.execute_cell(cell, index)
#      73     except CellExecutionError as ex:
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/engines.py:76, in catch_nb_assignment.<locals>.wrapper(self, *args, **kwargs)
#      73 if nb:
#      74     # Reassign if executing notebook object was replaced
#      75     self.nb = nb
# ---> 76 return func(self, *args, **kwargs)
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/engines.py:227, in NotebookExecutionManager.cell_start(self, cell, cell_index, **kwargs)
#     224 if cell_description is not None and hasattr(self, 'pbar') and self.pbar:
#     225     self.pbar.set_description(f"Executing {cell_description}")
# --> 227 self.save()
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/engines.py:76, in catch_nb_assignment.<locals>.wrapper(self, *args, **kwargs)
#      73 if nb:
#      74     # Reassign if executing notebook object was replaced
#      75     self.nb = nb
# ---> 76 return func(self, *args, **kwargs)
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/engines.py:145, in NotebookExecutionManager.save(self, **kwargs)
#     132 """
#     133 Saves the wrapped notebook state.
#     134
#    (...)
#     142 a 5 hour cell execution to capture output messages in the notebook.
#     143 """
#     144 if self.output_path:
# --> 145     write_ipynb(self.nb, self.output_path)
#     146 self.last_save_time = self.now()
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/iorw.py:499, in write_ipynb(nb, path)
#     493 def write_ipynb(nb, path):
#     494     """Saves a notebook object to the specified path.
#     495     Args:
#     496         nb_node (nbformat.NotebookNode): Notebook object to save.
#     497         notebook_path (str): Path to save the notebook object to.
#     498     """
# --> 499     papermill_io.write(nbformat.writes(nb), path)
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/iorw.py:106, in PapermillIO.write(self, buf, path, extensions)
#     105 def write(self, buf, path, extensions=['.ipynb', '.json']):
# --> 106     return self.get_handler(path, extensions).write(buf, path)
#
# File ~/Desktop/projects/Economy/venv/lib/python3.11/site-packages/papermill/iorw.py:227, in LocalHandler.write(self, buf, path)
#     225 if dirname and not os.path.exists(dirname):
#     226     raise FileNotFoundError("output folder {} doesn't exist.".format(dirname))
# --> 227 with io.open(path, 'w', encoding="utf-8") as f:
#     228     f.write(buf)
#
# KeyboardInterrupt:
